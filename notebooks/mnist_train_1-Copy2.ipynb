# %%
# !pip install torch torchquantum
# Out:
# Collecting torch
# Killed

# %%
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ded5ba42480f> in <module>
# ----> 1 s
#
# NameError: name 's' is not defined

# %%
# !pip install pennylane
# Out:
# Collecting pennylane
#   Using cached PennyLane-0.25.1-py3-none-any.whl (1.0 MB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/site-packages (from pennylane) (1.5.2)
# Collecting pennylane-lightning>=0.25
#   Using cached PennyLane_Lightning-0.25.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.6 MB)
# Requirement already satisfied: toml in /usr/local/lib/python3.7/site-packages (from pennylane) (0.10.2)
# Requirement already satisfied: retworkx in /usr/local/lib/python3.7/site-packages (from pennylane) (0.11.0)
# Collecting networkx
#   Using cached networkx-2.6.3-py3-none-any.whl (1.9 MB)
# Collecting semantic-version>=2.7
#   Using cached semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.7/site-packages (from pennylane) (4.2.2)
# Collecting autograd
#   Using cached autograd-1.4-py3-none-any.whl (48 kB)
# Collecting autoray>=0.3.1
#   Using cached autoray-0.3.2-py3-none-any.whl (36 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/site-packages (from pennylane) (1.21.6)
# Collecting appdirs
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting ninja
#   Using cached ninja-1.10.2.3-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (108 kB)
# Collecting future>=0.15.2
#   Using cached future-0.18.2-py3-none-any.whl
# Installing collected packages: ninja, future, semantic-version, pennylane-lightning, networkx, autoray, autograd, appdirs, pennylane
# Successfully installed appdirs-1.4.4 autograd-1.4 autoray-0.3.2 future-0.18.2 networkx-2.6.3 ninja-1.10.2.3 pennylane-0.25.1 pennylane-lightning-0.25.1 semantic-version-2.10.0
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# WARNING: You are using pip version 21.1.2; however, version 22.2.2 is available.
# You should consider upgrading via the '/usr/local/bin/python3.7 -m pip install --upgrade pip' command.

# %%
from importlib import reload

import datasets
import create_gate_circs
import train_circ

reload(datasets)
reload(create_gate_circs)
reload(train_circ)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-17-0338d76a7d12> in <module>
#       1 from importlib import reload
#       2
# ----> 3 import datasets
#       4 import create_gate_circs
#       5 import train_circ
#
# ~/datasets.py in <module>
#       1 import numpy as np
# ----> 2 import torch
#       3
#       4 class TorchDataset(torch.utils.data.Dataset):
#       5     def __init__(self, dataset_name, embed_type, reps, train=True, reshape_labels=False):
#
# ModuleNotFoundError: No module named 'torch'

# %%
from datasets import TorchDataset
from create_gate_circs import get_circ_params, TQCirc, generate_random_gate_circ
from train_circ import train_tq_model

import pickle as pkl
import torch
import os
import numpy as np

num_qubits = 10

device = torch.device('cpu')

dataset = 'mnist_10'

train_data = TorchDataset(dataset, 'angle', 1, True)
test_data = TorchDataset(dataset, 'angle', 1, False)

train_data_loader = torch.utils.data.DataLoader(train_data, batch_size=1, sampler=torch.utils.data.RandomSampler(train_data))
test_data_loader = torch.utils.data.DataLoader(train_data, batch_size=1024, sampler=torch.utils.data.RandomSampler(train_data))

val_test_data_loader = torch.utils.data.DataLoader(test_data, batch_size=100, sampler=torch.utils.data.SequentialSampler(test_data))

loss = torch.nn.functional.nll_loss
val_loss = torch.nn.NLLLoss(reduction='none')

for i in range(300, 333):
    curr_dir = './experiment_data/{}/trained_circuits/circ_{}'.format(dataset, i + 1)

    circ_gates, gate_params, inputs_bounds, weights_bounds = get_circ_params(curr_dir) 

    model = TQCirc(circ_gates, gate_params, inputs_bounds, weights_bounds, num_qubits, True).to(device)
    opt = torch.optim.SGD(model.parameters(), lr=0.05)
    
    losses_list = []
    accs_list = []
    
    for j in range(1):
        curr_train_dir = curr_dir + '/run_{}'.format(j + 1)

        if os.path.exists(curr_train_dir):
            pass
        else:
            os.mkdir(curr_train_dir)
    
        accs_history = train_tq_model(model, opt, loss, train_data_loader, test_data_loader, 120000, 1000, 1000)
        
#         curr_val_losses = []
#         curr_acc = 0
        
#         for k in range(100):
#             val_x, val_y = next(iter(val_test_data_loader))

#             val_preds = model(val_x)
#             curr_val_losses.append(val_loss(val_preds, val_y.to(torch.long)).detach().numpy().flatten())
        
#             val_class = torch.argmax(val_preds.detach(), 1).detach().numpy().flatten()

#             curr_acc += np.mean(val_class == val_y.detach().numpy().flatten())
        
#         np.save(curr_train_dir + '/accs_history_{}.npy'.format(j + 1), accs_history)
        
#         losses_list.append(curr_val_losses)
#         accs_list.append(curr_acc / 100)
        
#         print(curr_acc)
        
    torch.save(model.state_dict(), curr_dir + '/model.pt')
#     np.save(curr_dir + '/val_losses.npy', losses_list)
#     np.savetxt(curr_dir + '/accs.txt', accs_list)
# Out:
# Step 1 | Accuracy: 0.0478515625
# Step 1001 | Accuracy: 0.1650390625
# Step 2001 | Accuracy: 0.212890625
# Step 3001 | Accuracy: 0.2724609375
# Step 4001 | Accuracy: 0.287109375
# Step 5001 | Accuracy: 0.25
# Step 6001 | Accuracy: 0.27734375
# Step 7001 | Accuracy: 0.259765625
# Step 8001 | Accuracy: 0.2744140625
# Step 9001 | Accuracy: 0.294921875
# Step 10001 | Accuracy: 0.2861328125
# Step 11001 | Accuracy: 0.294921875
# Step 12001 | Accuracy: 0.2724609375
# Step 13001 | Accuracy: 0.2900390625
# Step 14001 | Accuracy: 0.2900390625
# Step 15001 | Accuracy: 0.2841796875
# Step 16001 | Accuracy: 0.3115234375
# Step 17001 | Accuracy: 0.314453125
# Step 18001 | Accuracy: 0.3212890625
# Step 19001 | Accuracy: 0.30859375
# Step 20001 | Accuracy: 0.3193359375
# Step 21001 | Accuracy: 0.3046875
# Step 22001 | Accuracy: 0.3173828125
# Step 23001 | Accuracy: 0.326171875
# Step 24001 | Accuracy: 0.3359375
# Step 25001 | Accuracy: 0.3134765625
# Step 26001 | Accuracy: 0.3095703125
# Step 27001 | Accuracy: 0.3154296875
# Step 28001 | Accuracy: 0.3076171875
# Step 29001 | Accuracy: 0.32421875
# Step 30001 | Accuracy: 0.310546875
# Step 31001 | Accuracy: 0.328125
# Step 32001 | Accuracy: 0.30859375
# Step 33001 | Accuracy: 0.3251953125
# Step 34001 | Accuracy: 0.3076171875
# Step 35001 | Accuracy: 0.337890625
# Step 36001 | Accuracy: 0.2900390625
# Step 37001 | Accuracy: 0.265625
# Step 38001 | Accuracy: 0.298828125
# Step 39001 | Accuracy: 0.326171875
# Step 40001 | Accuracy: 0.3154296875
# Step 41001 | Accuracy: 0.3037109375
# Step 42001 | Accuracy: 0.3037109375
# Step 43001 | Accuracy: 0.2900390625
# Step 44001 | Accuracy: 0.314453125
# Step 45001 | Accuracy: 0.2880859375
# Step 46001 | Accuracy: 0.2958984375
# Step 47001 | Accuracy: 0.310546875
# Step 48001 | Accuracy: 0.294921875
# Step 49001 | Accuracy: 0.349609375
# Step 50001 | Accuracy: 0.3359375
# Step 51001 | Accuracy: 0.326171875
# Step 52001 | Accuracy: 0.294921875
# Step 53001 | Accuracy: 0.318359375
# Step 54001 | Accuracy: 0.3154296875
# Step 55001 | Accuracy: 0.328125
# Step 56001 | Accuracy: 0.29296875
# Step 57001 | Accuracy: 0.275390625
# Step 58001 | Accuracy: 0.2802734375
# Step 59001 | Accuracy: 0.3173828125

# %%
from create_noise_models import noisy_dev_from_backend
from datasets_nt import load_dataset
from create_gate_circs import create_gate_circ, get_circ_params
from train_circ import train_qnn, mse_loss

import numpy as np
import os

dataset = 'mnist_2'

x_train, y_train, x_test, y_test = load_dataset(dataset, 'angle', 2)

num_qubits = 4
num_embeds = 32
num_params = 12

device_name = 'ibm_nairobi'

# dev = qml.device('lightning.qubit', wires=num_qubits)
dev = noisy_dev_from_backend(device_name, num_qubits)

for i in range(200, 400):
    curr_dir = './experiment_data/{}/trained_circuits/circ_{}'.format(dataset, i + 1)
    circ_gates, gate_params, inputs_bounds, weights_bounds = get_circ_params(curr_dir) 

    circ = create_gate_circ(dev, circ_gates, gate_params, inputs_bounds,
                                                    weights_bounds, [0], 'exp')
    
    
    noiseless_losses = np.genfromtxt(curr_dir + '/val_losses.txt')

    losses_list = []
    accs_list = []
    
    curr_dev_dir = curr_dir + '/' + device_name

#     if not os.path.exists(curr_dev_dir + '/accs_inference_only.txt'):
    if True:
        if not os.path.exists(curr_dev_dir):
            os.mkdir(curr_dev_dir)

        for j in range(5):
            curr_train_dir = curr_dir + '/run_{}'.format(j + 1)
            curr_params = np.genfromtxt(curr_train_dir + '/params_{}.txt'.format(j + 1))[-1]

            val_exps = [circ(x_test[i], curr_params) for i in range(len(x_test))]
            val_loss = np.array([mse_loss(y_test[k], val_exps[k]) for k in range(len(x_test))]).flatten()

#             acc = np.mean(np.sum(np.multiply(val_exps, y_test) > 0, 1) == 2)
            acc = np.mean(val_loss < 1)

            losses_list.append(val_loss)
            accs_list.append(acc)

        print(np.mean(noiseless_losses), np.mean(losses_list), i + 1)

        np.save(curr_dev_dir + '/val_losses_inference_only.npy', losses_list)
        np.savetxt(curr_dev_dir + '/accs_inference_only.txt', accs_list)
    else:
        print(i)
# Out:
# ibmqfactory.load_account:WARNING:2022-10-21 17:38:15,843: Credentials are already in use. The existing account in the session will be replaced.

# %% [markdown]
# ## fix bank errors

# %%
from datasets_nt import load_dataset
from create_gate_circs import create_gate_circ, get_circ_params
from train_circ import train_qnn, mse_vec_loss

import pennylane as qml
import numpy as np
import os

dataset = 'bank'

x_train, y_train, x_test, y_test = load_dataset(dataset, 'angle', 2)

num_qubits = 4
num_embeds = 8
num_params = 24

err_inds = np.array([[for j in range(5)] for i in range(8)]).flatten()

for i in range(875, 1000):
    curr_dir = './experiment_data/mnist_4/trained_circuits/circ_{}'.format(i + 1)
    circ_gates, gate_params, inputs_bounds, weights_bounds = get_circ_params(curr_dir) 

    circ = create_gate_circ(qml.device('lightning.qubit', wires=num_qubits), circ_gates, gate_params, inputs_bounds,
                                                    weights_bounds, [0, 1], 'exp')    

    losses_list = []
    accs_list = []
    
    for j in range(5):
        curr_train_dir = curr_dir + '/run_{}'.format(j + 1)

        if os.path.exists(curr_train_dir):
            pass
        else:
            os.mkdir(curr_train_dir)
    
        
        info = train_qnn(circ, x_train, y_train, x_test, y_test, [num_params], 16000, 0.05, 1, mse_vec_loss, verbosity=127300, 
                                                                                        loss_window=50, init_params=None, 
                                                                                        acc_thres=1.1, shuffle=True, print_loss=50)
        
        val_exps = [circ(x_test[i], info[-1][-1]) for i in range(len(x_test))]
        val_loss = np.array([mse_vec_loss(y_test[k], val_exps[k]) for k in range(len(x_test))]).flatten()

        acc = np.mean(np.sum(np.multiply(val_exps, y_test) > 0, 1) == 2)
        
        np.savetxt(curr_train_dir + '/params_{}.txt'.format(j + 1), info[-1])
        np.savetxt(curr_train_dir + '/losses_{}.txt'.format(j + 1), info[0])
        
        losses_list.append(val_loss)
        accs_list.append(acc)
        
    np.savetxt(curr_dir + '/val_losses.txt', losses_list)
    np.savetxt(curr_dir + '/accs.txt', accs_list)

# %% [markdown]
# ## supernet

# %%
def convert_supernet_circ_into_gate_circ(subnet, num_embeds, layer_rots, layer_cnots, num_qubits, angle_embed=False):
    circ_gates = []
    gate_params = []
    weights_bounds = [0]
    inputs_bounds = [0]

    curr_layers = subnet
    num_cnots = len(layer_cnots)
    
    for i in range(1):
        num_qubits = len(layer_rots[0])

        if angle_embed:
            rots = ['ry', 'rx', 'rz']
            
            for j in range(num_embeds):
                circ_gates += [rots[j % 3] for i in range(num_qubits)]
                gate_params += [[i] for i in range(num_qubits)]
                weights_bounds += [0 for i in range(num_qubits)]
                inputs_bounds += [inputs_bounds[-1] + i + 1 for i in range(2 * num_qubits - 1)]            
        else:
            for j in range(num_embeds):
                circ_gates += ['h' for i in range(num_qubits)] + ['ry' for i in range(num_qubits)] + ['cry' for i in range(num_qubits - 1)]
                gate_params += [[i] for i in range(num_qubits)] * 2 + [[i, i + 1] for i in range(num_qubits - 1)]
                weights_bounds += [0 for i in range(3 * num_qubits - 1)]
                inputs_bounds += [inputs_bounds[-1] for i in range(num_qubits)] + [inputs_bounds[-1] + i + 1 for i in range(2 * num_qubits - 1)]

        for j in range(len(curr_layers)):
            circ_gates += layer_rots[curr_layers[j] // num_cnots]
            circ_gates += ['cx' for k in layer_cnots[curr_layers[j] % num_cnots]]

            gate_params += [[k] for k in range(len(layer_rots[curr_layers[j] // num_cnots]))]
            gate_params += layer_cnots[curr_layers[j] % num_cnots]

            weights_bounds += [weights_bounds[-1] + k + 1 for k in range(num_qubits)]
            inputs_bounds += [inputs_bounds[-1] for k in range(num_qubits)]

            weights_bounds += [weights_bounds[-1] for k in range(len(layer_cnots[curr_layers[j] % num_cnots]))]
            inputs_bounds += [inputs_bounds[-1] for k in range(len(layer_cnots[curr_layers[j] % num_cnots]))]
            
    return circ_gates, gate_params, inputs_bounds, weights_bounds

# %%
import pennylane as qml
import numpy as np
import os

from datasets_nt import load_dataset
from create_gate_circs import create_batched_gate_circ
from create_noise_models import noisy_dev_from_backend

dataset = 'mnist_2'
main_dir = './supernet/mnist_2/'

x_train, y_train, x_test, y_test = load_dataset(dataset, 'supernet', 1)

num_qubits = 4
num_cnot_configs = 4096
num_circs = 2500
num_embed_layers = 4

device_name = 'ibm_nairobi'
# dev = qml.device('lightning.qubit', wires=num_qubits)
dev = noisy_dev_from_backend(device_name, num_qubits)

param_nums = [8, 12]

for p in param_nums:
    supernet_dir = main_dir + 'search-{}_params_mb'.format(p)

    num_layers = p // num_qubits

    layer_rots = open(supernet_dir + '/rotations.txt').read().split('\n')[:-1]
    layer_rots = [''.join([j for j in i if j.isupper()]) for i in layer_rots]
    layer_rots = [[i[j * 2:j * 2 + 2].lower() for j in range(len(i) // 2)] for i in layer_rots]

    layer_cnots = open(supernet_dir + '/cnots.txt').read().split('\n')[:-1]
    layer_cnots = [''.join([j for j in i[1:] if j not in ['[', ']', ',', ' ']]) for i in layer_cnots]
    layer_cnots = [[[int(i[2 * j]), int(i[2 * j + 1])] for j in range(len(i) // 2)] for i in layer_cnots]
        
    search_space = len(layer_rots) * len(layer_cnots)
        
    accs = []
    losses = []
    circ_layers = []

    params = np.genfromtxt(supernet_dir + '/training_params.txt')[-1].reshape((num_layers, search_space // num_cnot_configs, num_qubits))
        
    supernet_device_dir = supernet_dir + '/' + device_name
    
    if not os.path.exists(supernet_device_dir):
        os.mkdir(supernet_device_dir)
        
    for i in range(num_circs):
        curr_circ_desc = np.random.randint(0, search_space, num_layers)

        curr_params = np.concatenate([params[k, curr_circ_desc[k] // num_cnot_configs] for k in range(num_layers)]).flatten()

        circ_gates, gate_params, inputs_bounds, weights_bounds = convert_supernet_circ_into_gate_circ(curr_circ_desc, num_embed_layers, layer_rots, layer_cnots,
                                                                                                          num_qubits, False) 

        
        circ = create_batched_gate_circ(dev, circ_gates, gate_params, inputs_bounds,
                                                                weights_bounds, [0], 'exp')

        val_exp_list = []
        
        for j in range(np.ceil(len(x_test) / 32).astype('int32')):
            curr_batch_params = np.concatenate([[curr_params] for k in range(min(32, len(x_test) - 32 * j))], 0)
            
            val_exp_list.append(circ(x_test[32 * j:min(len(x_test), 32* j + 32)], curr_batch_params))
            
        val_exps = np.concatenate(val_exp_list)
        val_losses = np.power(val_exps - y_test, 2)
        val_loss = np.mean(val_losses)
        acc = np.mean(val_losses < 1)
            
        print(curr_circ_desc, acc, val_loss)

        accs.append(acc)
        losses.append(val_loss)
        circ_layers.append(curr_circ_desc)
        
    np.savetxt(supernet_device_dir + '/searched_circ_layers.txt', np.array(circ_layers))
    np.savetxt(supernet_device_dir + '/searched_circ_accs.txt', accs)
    np.savetxt(supernet_device_dir + '/searched_circ_losses.txt', losses)
# Out:
# ibmqfactory.load_account:WARNING:2022-10-07 17:50:00,677: Credentials are already in use. The existing account in the session will be replaced.

# %%
from datasets_nt import load_dataset
from create_gate_circs import create_gate_circ
from train_circ import mse_loss, train_qnn
from create_noise_models import noisy_dev_from_backend

import pennylane as qml
import numpy as np
import os

dataset = 'mnist_2'
main_dir = './supernet/mnist_2/'

x_train, y_train, x_test, y_test = load_dataset(dataset, 'supernet', 1)

num_qubits = 4
num_cnot_configs = 4096
num_circs = 2500
num_embed_layers = 4
meas_qubits = [0]
num_steps = 8000

dev = qml.device('lightning.qubit', wires=num_qubits)

param_nums = [20]
search_nums = [100]
num_trials = [25]

device_name = 'ibmq_lima'
noisy_dev = noisy_dev_from_backend(device_name, num_qubits)

for p in param_nums:
    curr_params_dir =  main_dir + 'search-{}_params_mb'.format(p)

    layer_rots = open(curr_params_dir + '/rotations.txt').read().split('\n')[:-1]
    layer_rots = [''.join([j for j in i if j.isupper()]) for i in layer_rots]
    layer_rots = [[i[j * 2:j * 2 + 2].lower() for j in range(len(i) // 2)] for i in layer_rots]

    layer_cnots = open(curr_params_dir + '/cnots.txt').read().split('\n')[:-1]
    layer_cnots = [''.join([j for j in i[1:] if j not in ['[', ']', ',', ' ']]) for i in layer_cnots]
    layer_cnots = [[[int(i[2 * j]), int(i[2 * j + 1])] for j in range(len(i) // 2)] for i in layer_cnots]
        
    circ_accs = np.genfromtxt(curr_params_dir + '/{}/searched_circ_accs.txt'.format(device_name))
    circ_losses = np.genfromtxt(curr_params_dir + '/{}/searched_circ_losses.txt'.format(device_name))
    circ_layers = np.genfromtxt(curr_params_dir + '/{}/searched_circ_layers.txt'.format(device_name)).astype('int32').reshape((num_circs, p // num_qubits))

    for k in range(len(search_nums)):
        search_dir = curr_params_dir + '/{}/search_{}'.format(device_name, search_nums[k])

        if not os.path.exists(search_dir):
            os.mkdir(search_dir)

        for i in range(10, 25):
            curr_dir = search_dir + '/trial_{}'.format(i + 1)

            if not os.path.exists(curr_dir):
                os.mkdir(curr_dir)

            chosen_circs = range(search_nums[k] * i, search_nums[k] * i + search_nums[k])
            best_circuit_ind = chosen_circs[np.argmax(circ_accs[chosen_circs])]
            best_subnet = circ_layers[best_circuit_ind]
            print(circ_accs[best_circuit_ind], circ_losses[best_circuit_ind], best_subnet)

            np.savetxt(curr_dir + '/sampled_circuits.txt', circ_layers[chosen_circs])
            np.savetxt(curr_dir + '/sampled_circuit_accs.txt', circ_accs[chosen_circs])

            circ_gates, gate_params, inputs_bounds, weights_bounds = convert_supernet_circ_into_gate_circ(best_subnet, num_embed_layers,
                                                                                                              layer_rots, layer_cnots, num_qubits, False)

            circ = create_gate_circ(dev, circ_gates, gate_params, inputs_bounds,
                                                                weights_bounds, meas_qubits, 'exp', 'adjoint') 
            
            noisy_circ = create_gate_circ(noisy_dev, circ_gates, gate_params, inputs_bounds,
                                                                weights_bounds, meas_qubits, 'exp', None)

            losses_list = []
            accs_list = []
            
            noisy_losses_list = []
            noisy_accs_list = []

            for j in range(5):
                curr_train_dir = curr_dir + '/run_{}'.format(j + 1)

                if os.path.exists(curr_train_dir):
                    pass
                else:
                    os.mkdir(curr_train_dir)


                info = train_qnn(circ, x_train, y_train, x_test, y_test, [weights_bounds[-1]], num_steps, 0.05, 1, mse_loss, verbosity=17300, 
                                                                                                    loss_window=50, init_params=None, 
                                                                                                    acc_thres=1.1, shuffle=True, print_loss=50)
                
                np.savetxt(curr_train_dir + '/params_{}.txt'.format(j + 1), info[-1])
                np.savetxt(curr_train_dir + '/losses_{}.txt'.format(j + 1), info[0])

                val_exps = [circ(x_test[i], info[-1][-1]) for i in range(len(x_test))]
                val_loss = np.array([mse_loss(y_test[k], val_exps[k]) for k in range(len(x_test))]).flatten()
                                
                noisy_val_exps = [noisy_circ(x_test[i], info[-1][-1]) for i in range(len(x_test))]
                noisy_val_loss = np.array([mse_loss(y_test[k], noisy_val_exps[k]) for k in range(len(x_test))]).flatten()

                acc = np.mean(val_loss < 1)
                noisy_acc = np.mean(noisy_val_loss < 1)

                losses_list.append(val_loss)
                accs_list.append(acc)
                
                noisy_losses_list.append(noisy_val_loss)
                noisy_accs_list.append(noisy_acc)

            np.savetxt(curr_dir + '/accs.txt', accs_list)
            np.savetxt(curr_dir + '/val_losses.txt', losses_list)          
            
            np.savetxt(curr_dir + '/noisy_accs.txt', noisy_accs_list)
            np.savetxt(curr_dir + '/noisy_val_losses.txt', noisy_losses_list)  

            np.savetxt(curr_dir + '/gates.txt', circ_gates, fmt="%s")
            np.savetxt(curr_dir + '/gate_params.txt', gate_params, fmt="%s")
            np.savetxt(curr_dir + '/inputs_bounds.txt', inputs_bounds)
            np.savetxt(curr_dir + '/weights_bounds.txt', weights_bounds)
            np.savetxt(curr_dir + '/layers.txt', best_subnet)
# Out:
# /usr/local/lib/python3.7/site-packages/qiskit_aer/noise/device/models.py:367: UserWarning: Device model returned an invalid T_2 relaxation time greater than the theoretical maximum value 2 * T_1 (193259.0410847615 > 2 * 90304.57161775761). Truncating to maximum value.
#   " Truncating to maximum value.", UserWarning)
# /usr/local/lib/python3.7/site-packages/qiskit_aer/noise/device/models.py:367: UserWarning: Device model returned an invalid T_2 relaxation time greater than the theoretical maximum value 2 * T_1 (193259.0410847615 > 2 * 90304.57161775761). Truncating to maximum value.
#   " Truncating to maximum value.", UserWarning)
# /usr/local/lib/python3.7/site-packages/qiskit_aer/noise/device/models.py:367: UserWarning: Device model returned an invalid T_2 relaxation time greater than the theoretical maximum value 2 * T_1 (193259.0410847615 > 2 * 90304.57161775761). Truncating to maximum value.
#   " Truncating to maximum value.", UserWarning)
# /usr/local/lib/python3.7/site-packages/qiskit_aer/noise/device/models.py:367: UserWarning: Device model returned an invalid T_2 relaxation time greater than the theoretical maximum value 2 * T_1 (193259.0410847615 > 2 * 90304.57161775761). Truncating to maximum value.
#   " Truncating to maximum value.", UserWarning)
# /usr/local/lib/python3.7/site-packages/qiskit_aer/noise/device/models.py:367: UserWarning: Device model returned an invalid T_2 relaxation time greater than the theoretical maximum value 2 * T_1 (193259.0410847615 > 2 * 90304.57161775761). Truncating to maximum value.
#   " Truncating to maximum value.", UserWarning)
# /usr/local/lib/python3.7/site-packages/qiskit_aer/noise/device/models.py:367: UserWarning: Device model returned an invalid T_2 relaxation time greater than the theoretical maximum value 2 * T_1 (193259.0410847615 > 2 * 90304.57161775761). Truncating to maximum value.
#   " Truncating to maximum value.", UserWarning)
# /usr/local/lib/python3.7/site-packages/qiskit_aer/noise/device/models.py:367: UserWarning: Device model returned an invalid T_2 relaxation time greater than the theoretical maximum value 2 * T_1 (0.0001932590410847615 > 2 * 9.030457161775761e-05). Truncating to maximum value.
#   " Truncating to maximum value.", UserWarning)
# 0.5675 1.0075315380096435 [284510 280432 278685 155525 214053]
# [2022-10-13 14:59:51.625 tensorflow-2-3-cpu-py-ml-t3-medium-dbca98283d57d615662c4efa28c8:27 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2022-10-13 14:59:51.737 tensorflow-2-3-cpu-py-ml-t3-medium-dbca98283d57d615662c4efa28c8:27 INFO profiler_config_parser.py:102] Unable to find config at /opt/ml/input/config/profilerconfig.json. Profiler is disabled.
# Step 1 | Sliding Loss Window : 1.1687044805071023
# Step 51 | Sliding Loss Window : 1.1402462199108623
# Step 101 | Sliding Loss Window : 1.0437048649701115
# Step 151 | Sliding Loss Window : 1.0396026566029086
# Step 201 | Sliding Loss Window : 1.062623836958626
# Step 251 | Sliding Loss Window : 1.0298366369545082
# Step 301 | Sliding Loss Window : 1.0179686008929167
# Step 351 | Sliding Loss Window : 1.0607351176513753
# Step 401 | Sliding Loss Window : 1.0554055148564374
# Step 451 | Sliding Loss Window : 1.024237281303757
# Step 501 | Sliding Loss Window : 1.0067491621465872
# Step 551 | Sliding Loss Window : 1.0826915742478649
# Step 601 | Sliding Loss Window : 0.9403020699455834
# Step 651 | Sliding Loss Window : 1.087846536071754
# Step 701 | Sliding Loss Window : 1.046336070387854
# Step 751 | Sliding Loss Window : 1.0115559752963916
# Step 801 | Sliding Loss Window : 0.9564915541093549
# Step 851 | Sliding Loss Window : 0.9853389208942096
# Step 901 | Sliding Loss Window : 1.04689321509362
# Step 951 | Sliding Loss Window : 1.093287724593186
# Step 1001 | Sliding Loss Window : 1.0030114363114067
# Step 1051 | Sliding Loss Window : 1.0020580899324316
# Step 1101 | Sliding Loss Window : 1.099197950717469
# Step 1151 | Sliding Loss Window : 1.0262557236108778
# Step 1201 | Sliding Loss Window : 0.9862075062673221
# Step 1251 | Sliding Loss Window : 0.933754414013192
# Step 1301 | Sliding Loss Window : 1.0982732681176086
# Step 1351 | Sliding Loss Window : 1.1730679958018562
# Step 1401 | Sliding Loss Window : 0.9996183184596751
# Step 1451 | Sliding Loss Window : 1.0538897829966907
# Step 1501 | Sliding Loss Window : 1.0115014869441123
# Step 1551 | Sliding Loss Window : 1.0846286361649922
# Step 1601 | Sliding Loss Window : 1.1068595864003052
# Step 1651 | Sliding Loss Window : 0.9759717558804821
# Step 1701 | Sliding Loss Window : 0.967167204744287
# Step 1751 | Sliding Loss Window : 1.1014123487726197
# Step 1801 | Sliding Loss Window : 1.1097227922728474
# Step 1851 | Sliding Loss Window : 1.062158870769243
# Step 1901 | Sliding Loss Window : 1.0631102986930203
# Step 1951 | Sliding Loss Window : 1.0686877466448774
# Step 2001 | Sliding Loss Window : 1.0425178044119052
# Step 2051 | Sliding Loss Window : 1.0346429131757697
# Step 2101 | Sliding Loss Window : 0.9773510752042398
# Step 2151 | Sliding Loss Window : 1.0735192021819069
# Step 2201 | Sliding Loss Window : 0.940692533832446
# Step 2251 | Sliding Loss Window : 1.0652891734779957
# Step 2301 | Sliding Loss Window : 1.0218965565145917
# Step 2351 | Sliding Loss Window : 1.0301356404802275
# Step 2401 | Sliding Loss Window : 0.9271637523338626
# Step 2451 | Sliding Loss Window : 0.9524269049811848
# Step 2501 | Sliding Loss Window : 1.0197748229465753
# Step 2551 | Sliding Loss Window : 1.0821826421845377
# Step 2601 | Sliding Loss Window : 1.023585257398719
# Step 2651 | Sliding Loss Window : 0.9721269528403963
# Step 2701 | Sliding Loss Window : 1.09775003212732
# Step 2751 | Sliding Loss Window : 1.0249948440484835
# Step 2801 | Sliding Loss Window : 1.0370717722935343
# Step 2851 | Sliding Loss Window : 0.9644776629754829
# Step 2901 | Sliding Loss Window : 1.0843194342356948
# Step 2951 | Sliding Loss Window : 1.1465905722493728
# Step 3001 | Sliding Loss Window : 0.9905828066733293
# Step 3051 | Sliding Loss Window : 1.0829455144459288
# Step 3101 | Sliding Loss Window : 0.9543674150637709
# Step 3151 | Sliding Loss Window : 1.036142335547581
# Step 3201 | Sliding Loss Window : 1.1318573457817762
# Step 3251 | Sliding Loss Window : 0.9506750755478207
# Step 3301 | Sliding Loss Window : 0.962490846643166
# Step 3351 | Sliding Loss Window : 1.080668996437478
# Step 3401 | Sliding Loss Window : 1.0535077435207953
# Step 3451 | Sliding Loss Window : 1.010293719207867
# Step 3501 | Sliding Loss Window : 0.9891519702487203
# Step 3551 | Sliding Loss Window : 1.0324170734023825
# Step 3601 | Sliding Loss Window : 1.0369168243390106
# Step 3651 | Sliding Loss Window : 1.0097197897356873
# Step 3701 | Sliding Loss Window : 1.0121379350847108
# Step 3751 | Sliding Loss Window : 1.04347861013225
# Step 3801 | Sliding Loss Window : 1.026124862073707
# Step 3851 | Sliding Loss Window : 1.0293492257963863
# Step 3901 | Sliding Loss Window : 1.0503467358043856
# Step 3951 | Sliding Loss Window : 0.9671942877755814
# Step 4001 | Sliding Loss Window : 0.8778531528262212
# Step 4051 | Sliding Loss Window : 0.9354315321936787
# Step 4101 | Sliding Loss Window : 0.9693332880839901
# Step 4151 | Sliding Loss Window : 1.0996461047915405
# Step 4201 | Sliding Loss Window : 0.9914713646046163
# Step 4251 | Sliding Loss Window : 0.9942954692212719
# Step 4301 | Sliding Loss Window : 1.0748527270484884
# Step 4351 | Sliding Loss Window : 0.9916491834186567
# Step 4401 | Sliding Loss Window : 1.0676043864337104
# Step 4451 | Sliding Loss Window : 1.0191411033356013
# Step 4501 | Sliding Loss Window : 1.013030019036663
# Step 4551 | Sliding Loss Window : 1.054148683489379
# Step 4601 | Sliding Loss Window : 1.007532746453699
# Step 4651 | Sliding Loss Window : 1.0725586501109312
# Step 4701 | Sliding Loss Window : 0.9985088877062502
# Step 4751 | Sliding Loss Window : 1.0245019722446664
# Step 4801 | Sliding Loss Window : 1.032820886462717
# Step 4851 | Sliding Loss Window : 1.0089735423939616
# Step 4901 | Sliding Loss Window : 0.994381710584391
# Step 4951 | Sliding Loss Window : 1.0346290250168932
# Step 5001 | Sliding Loss Window : 1.006599804872385
# Step 5051 | Sliding Loss Window : 1.006245000542958
# Step 5101 | Sliding Loss Window : 0.9557824809663917
# Step 5151 | Sliding Loss Window : 1.0303671845879179
# Step 5201 | Sliding Loss Window : 1.0164492423714646
# Step 5251 | Sliding Loss Window : 1.027978965583938
# Step 5301 | Sliding Loss Window : 1.0215160965102976
# Step 5351 | Sliding Loss Window : 1.0468210925674408
# Step 5401 | Sliding Loss Window : 1.0231572283427408
# Step 5451 | Sliding Loss Window : 1.0137994703898432
# Step 5501 | Sliding Loss Window : 1.0501462417699903
# Step 5551 | Sliding Loss Window : 0.9596202739594724
# Step 5601 | Sliding Loss Window : 0.863650674969783
# Step 5651 | Sliding Loss Window : 0.9124211050725204
# Step 5701 | Sliding Loss Window : 0.9637252883542472
# Step 5751 | Sliding Loss Window : 1.100439069855004
# Step 5801 | Sliding Loss Window : 1.0187183471172694
# Step 5851 | Sliding Loss Window : 0.979273229938983
# Step 5901 | Sliding Loss Window : 1.0483704473815942
# Step 5951 | Sliding Loss Window : 1.0246918279568389
# Step 6001 | Sliding Loss Window : 1.0868299301739057
# Step 6051 | Sliding Loss Window : 0.9989461463897159
# Step 6101 | Sliding Loss Window : 1.007487722317559
# Step 6151 | Sliding Loss Window : 1.0558632485767458
# Step 6201 | Sliding Loss Window : 1.0214623260050437
# Step 6251 | Sliding Loss Window : 1.1032247773478254
# Step 6301 | Sliding Loss Window : 1.0405226579038125
# Step 6351 | Sliding Loss Window : 1.0097701133329848
# Step 6401 | Sliding Loss Window : 1.0095675082571782
# Step 6451 | Sliding Loss Window : 0.9991823227834605
# Step 6501 | Sliding Loss Window : 0.9901601762169336
# Step 6551 | Sliding Loss Window : 1.0796135313461175
# Step 6601 | Sliding Loss Window : 1.0238810815637198
# Step 6651 | Sliding Loss Window : 1.010940386250224
# Step 6701 | Sliding Loss Window : 0.959347146929976
# Step 6751 | Sliding Loss Window : 1.03422341449577
# Step 6801 | Sliding Loss Window : 1.0027676715904272
# Step 6851 | Sliding Loss Window : 1.012734549421231
# Step 6901 | Sliding Loss Window : 1.0124025482843357
# Step 6951 | Sliding Loss Window : 1.053752285743553
# Step 7001 | Sliding Loss Window : 1.0284314556862568
# Step 7051 | Sliding Loss Window : 0.9980639992134726
# Step 7101 | Sliding Loss Window : 1.0498439315342918
# Step 7151 | Sliding Loss Window : 0.9387424052244415
# Step 7201 | Sliding Loss Window : 0.8745100655411694
# Step 7251 | Sliding Loss Window : 0.9184674122776804
# Step 7301 | Sliding Loss Window : 0.944858776830198
# Step 7351 | Sliding Loss Window : 1.086331429718983
# Step 7401 | Sliding Loss Window : 1.0407450695760618
# Step 7451 | Sliding Loss Window : 0.963880245394195
# Step 7501 | Sliding Loss Window : 1.0520857344262402
# Step 7551 | Sliding Loss Window : 1.0060255294328064
# Step 7601 | Sliding Loss Window : 1.0659016747326564
# Step 7651 | Sliding Loss Window : 1.015283107831169
# Step 7701 | Sliding Loss Window : 1.028935066814794
# Step 7751 | Sliding Loss Window : 1.0515590609159688
# Step 7801 | Sliding Loss Window : 1.0272163473231637
# Step 7851 | Sliding Loss Window : 1.1091730741464338
# Step 7901 | Sliding Loss Window : 1.0498463808325509
# Step 7951 | Sliding Loss Window : 1.0107519923823731
# Step 1 | Sliding Loss Window : 1.1526732338768486
# Step 51 | Sliding Loss Window : 1.1119512190762373
# Step 101 | Sliding Loss Window : 1.0614285468741482
# Step 151 | Sliding Loss Window : 0.9426617314301372
# Step 201 | Sliding Loss Window : 1.0724297186680907
# Step 251 | Sliding Loss Window : 0.9548816505019049
# Step 301 | Sliding Loss Window : 1.0225942009634612
# Step 351 | Sliding Loss Window : 1.0183740905353325
# Step 401 | Sliding Loss Window : 1.0700174467076402
# Step 451 | Sliding Loss Window : 0.9716885566614146
# Step 501 | Sliding Loss Window : 1.0335049661564686
# Step 551 | Sliding Loss Window : 1.0715744337366326
# Step 601 | Sliding Loss Window : 1.0917283888890088
# Step 651 | Sliding Loss Window : 1.014825301190702
# Step 701 | Sliding Loss Window : 0.9638051872350801
# Step 751 | Sliding Loss Window : 1.0916535585784441
# Step 801 | Sliding Loss Window : 0.9413670358337132
# Step 851 | Sliding Loss Window : 1.0317147500309334
# Step 901 | Sliding Loss Window : 1.048408481514976
# Step 951 | Sliding Loss Window : 1.0334860497182108
# Step 1001 | Sliding Loss Window : 1.027936186894736
# Step 1051 | Sliding Loss Window : 1.0084244935761104
# Step 1101 | Sliding Loss Window : 1.0107021619350387
# Step 1151 | Sliding Loss Window : 1.0084216400842019
# Step 1201 | Sliding Loss Window : 1.0260084244397905
# Step 1251 | Sliding Loss Window : 1.0396100920007654
# Step 1301 | Sliding Loss Window : 0.9986241419015282
# Step 1351 | Sliding Loss Window : 1.0084545428825495
# Step 1401 | Sliding Loss Window : 0.9850005466181239
# Step 1451 | Sliding Loss Window : 0.9904947471860607
# Step 1501 | Sliding Loss Window : 1.0803486023323097
# Step 1551 | Sliding Loss Window : 1.0119665494569619
# Step 1601 | Sliding Loss Window : 0.9684876611628532
# Step 1651 | Sliding Loss Window : 0.9678292453886239
# Step 1701 | Sliding Loss Window : 1.0595395807957715
# Step 1751 | Sliding Loss Window : 1.0552119826094568
# Step 1801 | Sliding Loss Window : 1.0050327499485237
# Step 1851 | Sliding Loss Window : 1.002878020130425
# Step 1901 | Sliding Loss Window : 0.9787119363578981
# Step 1951 | Sliding Loss Window : 1.0375917361559623
# Step 2001 | Sliding Loss Window : 1.0166161983656503
# Step 2051 | Sliding Loss Window : 0.9983179038944305
# Step 2101 | Sliding Loss Window : 0.993641809986839
# Step 2151 | Sliding Loss Window : 0.9987257277914757
# Step 2201 | Sliding Loss Window : 1.0232538751711069
# Step 2251 | Sliding Loss Window : 1.0351404283915184
# Step 2301 | Sliding Loss Window : 1.0123414683062466
# Step 2351 | Sliding Loss Window : 1.0454099923061257
# Step 2401 | Sliding Loss Window : 0.968065808731039
# Step 2451 | Sliding Loss Window : 1.0103615746656316
# Step 2501 | Sliding Loss Window : 1.0511292682399545
# Step 2551 | Sliding Loss Window : 1.0308895898541344
# Step 2601 | Sliding Loss Window : 1.0258818518491508
# Step 2651 | Sliding Loss Window : 0.9898204505401493
# Step 2701 | Sliding Loss Window : 1.0091205656099844
# Step 2751 | Sliding Loss Window : 0.9832492162332599
# Step 2801 | Sliding Loss Window : 1.027612706484328
# Step 2851 | Sliding Loss Window : 1.0450540300774656
# Step 2901 | Sliding Loss Window : 0.9901815459416556
# Step 2951 | Sliding Loss Window : 1.0030450815205574
# Step 3001 | Sliding Loss Window : 1.0050532803607384
# Step 3051 | Sliding Loss Window : 0.9681188558695486
# Step 3101 | Sliding Loss Window : 1.0483890407507248
# Step 3151 | Sliding Loss Window : 0.9760279561813671
# Step 3201 | Sliding Loss Window : 0.9844616053409867
# Step 3251 | Sliding Loss Window : 0.9254494049080694
# Step 3301 | Sliding Loss Window : 1.0127763563136858
# Step 3351 | Sliding Loss Window : 1.0588287402576597
# Step 3401 | Sliding Loss Window : 1.0381413197346596
# Step 3451 | Sliding Loss Window : 0.9580433218392865
# Step 3501 | Sliding Loss Window : 0.976525123138622
# Step 3551 | Sliding Loss Window : 1.0817916995555548
# Step 3601 | Sliding Loss Window : 1.0208613142659821
# Step 3651 | Sliding Loss Window : 0.9892275616239814
# Step 3701 | Sliding Loss Window : 1.000458069364918
# Step 3751 | Sliding Loss Window : 1.0214943601023518
# Step 3801 | Sliding Loss Window : 1.019736063460702
# Step 3851 | Sliding Loss Window : 1.0375865212112259
# Step 3901 | Sliding Loss Window : 1.0351819694417668
# Step 3951 | Sliding Loss Window : 1.0422172832810914
# Step 4001 | Sliding Loss Window : 1.0063602437255312
# Step 4051 | Sliding Loss Window : 1.0083153370181
# Step 4101 | Sliding Loss Window : 1.0018863825430373
# Step 4151 | Sliding Loss Window : 1.0442803759212549
# Step 4201 | Sliding Loss Window : 1.0354681458256807
# Step 4251 | Sliding Loss Window : 0.9998126294005079
# Step 4301 | Sliding Loss Window : 1.0125590782547114
# Step 4351 | Sliding Loss Window : 0.9905304095577365
# Step 4401 | Sliding Loss Window : 1.028868763607274
# Step 4451 | Sliding Loss Window : 1.0246733892095392
# Step 4501 | Sliding Loss Window : 0.9964059852968657
# Step 4551 | Sliding Loss Window : 1.009610418445479
# Step 4601 | Sliding Loss Window : 1.0316285546705801
# Step 4651 | Sliding Loss Window : 1.0116049662033206
# Step 4701 | Sliding Loss Window : 1.0057768570149863
# Step 4751 | Sliding Loss Window : 0.9741551958580007
# Step 4801 | Sliding Loss Window : 0.9650600541530497
# Step 4851 | Sliding Loss Window : 0.9417290037214947
# Step 4901 | Sliding Loss Window : 0.9934678302385934
# Step 4951 | Sliding Loss Window : 1.0652656181516194
# Step 5001 | Sliding Loss Window : 1.0393905351729196
# Step 5051 | Sliding Loss Window : 0.9308510698351433
# Step 5101 | Sliding Loss Window : 0.952316959194606
# Step 5151 | Sliding Loss Window : 1.1027121828640174
# Step 5201 | Sliding Loss Window : 1.0281180280414792
# Step 5251 | Sliding Loss Window : 1.0015190604207294
# Step 5301 | Sliding Loss Window : 1.0066532810893163
# Step 5351 | Sliding Loss Window : 1.0176139847082768
# Step 5401 | Sliding Loss Window : 1.0175778807653892
# Step 5451 | Sliding Loss Window : 1.037909532027121
# Step 5501 | Sliding Loss Window : 1.0490406977317037
# Step 5551 | Sliding Loss Window : 1.0394564465793221
# Step 5601 | Sliding Loss Window : 1.0005147255980424
# Step 5651 | Sliding Loss Window : 1.012209044680128
# Step 5701 | Sliding Loss Window : 1.0092786696626435
# Step 5751 | Sliding Loss Window : 1.0496652308717913
# Step 5801 | Sliding Loss Window : 1.0215432864654714
# Step 5851 | Sliding Loss Window : 1.01348740192932
# Step 5901 | Sliding Loss Window : 1.0145806079695872
# Step 5951 | Sliding Loss Window : 0.9893519241652272
# Step 6001 | Sliding Loss Window : 0.9820824800647671
# Step 6051 | Sliding Loss Window : 1.0189645692487808
# Step 6101 | Sliding Loss Window : 1.0005170166973802
# Step 6151 | Sliding Loss Window : 1.0183969325920679
# Step 6201 | Sliding Loss Window : 1.0264569564447361
# Step 6251 | Sliding Loss Window : 1.023903690747248
# Step 6301 | Sliding Loss Window : 0.9935182635987077
# Step 6351 | Sliding Loss Window : 1.0057087850608981
# Step 6401 | Sliding Loss Window : 0.957683244256902
# Step 6451 | Sliding Loss Window : 0.9800965416904261
# Step 6501 | Sliding Loss Window : 0.998917314744273
# Step 6551 | Sliding Loss Window : 1.0453280820353976
# Step 6601 | Sliding Loss Window : 1.0210719306834553
# Step 6651 | Sliding Loss Window : 0.9296419880654426
# Step 6701 | Sliding Loss Window : 0.9523201592775371
# Step 6751 | Sliding Loss Window : 1.0842955493154205
# Step 6801 | Sliding Loss Window : 1.0205700339301662
# Step 6851 | Sliding Loss Window : 1.0127537711233103
# Step 6901 | Sliding Loss Window : 1.0068754539037315
# Step 6951 | Sliding Loss Window : 1.0041464600562922
# Step 7001 | Sliding Loss Window : 0.9941193004530046
# Step 7051 | Sliding Loss Window : 1.0389283646487026
# Step 7101 | Sliding Loss Window : 1.0574621082814688
# Step 7151 | Sliding Loss Window : 1.0319786234916222
# Step 7201 | Sliding Loss Window : 0.9809144045428169
# Step 7251 | Sliding Loss Window : 1.0095243158127944
# Step 7301 | Sliding Loss Window : 1.0337504590393944
# Step 7351 | Sliding Loss Window : 1.032225094277556
# Step 7401 | Sliding Loss Window : 1.015463405709144
# Step 7451 | Sliding Loss Window : 1.0218909269069776
# Step 7501 | Sliding Loss Window : 1.0298492845782823
# Step 7551 | Sliding Loss Window : 0.9843439092195834
# Step 7601 | Sliding Loss Window : 0.9908215709870657
# Step 7651 | Sliding Loss Window : 1.0196646024963065
# Step 7701 | Sliding Loss Window : 1.0006689755835643
# Step 7751 | Sliding Loss Window : 1.0269839460984365
# Step 7801 | Sliding Loss Window : 1.0198969606143957
# Step 7851 | Sliding Loss Window : 1.0223857244683436
# Step 7901 | Sliding Loss Window : 0.9850330284924297
# Step 7951 | Sliding Loss Window : 1.0208083515310384
# Step 1 | Sliding Loss Window : 0.2894943866814102
# Step 51 | Sliding Loss Window : 1.0770673833855937
# Step 101 | Sliding Loss Window : 0.9900791079921697
# Step 151 | Sliding Loss Window : 1.0976751142999612
# Step 201 | Sliding Loss Window : 1.0634281515016368
# Step 251 | Sliding Loss Window : 0.9864448477466408
# Step 301 | Sliding Loss Window : 1.0710490190188948
# Step 351 | Sliding Loss Window : 1.0305592149250615
# Step 401 | Sliding Loss Window : 1.0477668774118272
# Step 451 | Sliding Loss Window : 1.039932608665764
# Step 501 | Sliding Loss Window : 1.063462218629031
# Step 551 | Sliding Loss Window : 1.0049797279371184
# Step 601 | Sliding Loss Window : 1.0758493365583213
# Step 651 | Sliding Loss Window : 1.0452997741890704
# Step 701 | Sliding Loss Window : 1.0717073712694718
# Step 751 | Sliding Loss Window : 1.0461051526829248
# Step 801 | Sliding Loss Window : 1.0073142139547528
# Step 851 | Sliding Loss Window : 0.9509413462587136
# Step 901 | Sliding Loss Window : 1.0236897954212376
# Step 951 | Sliding Loss Window : 1.035653110068153
# Step 1001 | Sliding Loss Window : 1.0532092186055704
# Step 1051 | Sliding Loss Window : 1.0286256252317387
# Step 1101 | Sliding Loss Window : 0.9927135394261231
# Step 1151 | Sliding Loss Window : 1.0100857990942271
# Step 1201 | Sliding Loss Window : 0.9706865485210896
# Step 1251 | Sliding Loss Window : 1.0503896552486838
# Step 1301 | Sliding Loss Window : 0.9465840017406231
# Step 1351 | Sliding Loss Window : 1.120276660627673
# Step 1401 | Sliding Loss Window : 0.9869612197907341
# Step 1451 | Sliding Loss Window : 1.0523887248111825
# Step 1501 | Sliding Loss Window : 1.0344421004482944
# Step 1551 | Sliding Loss Window : 1.0429933252127443
# Step 1601 | Sliding Loss Window : 1.0086518847209347
# Step 1651 | Sliding Loss Window : 1.0506796792723176
# Step 1701 | Sliding Loss Window : 1.0580241710943514
# Step 1751 | Sliding Loss Window : 1.0503150018316192
# Step 1801 | Sliding Loss Window : 1.042969404111639
# Step 1851 | Sliding Loss Window : 1.0223340318351246
# Step 1901 | Sliding Loss Window : 1.0253434815560336
# Step 1951 | Sliding Loss Window : 1.0150586684866139
# Step 2001 | Sliding Loss Window : 1.0652485287850078
# Step 2051 | Sliding Loss Window : 1.0337917019655902
# Step 2101 | Sliding Loss Window : 1.0099538808437891
# Step 2151 | Sliding Loss Window : 0.9568392853029711
# Step 2201 | Sliding Loss Window : 1.0677222112300526
# Step 2251 | Sliding Loss Window : 1.0079340667115309
# Step 2301 | Sliding Loss Window : 0.9768894716071839
# Step 2351 | Sliding Loss Window : 1.0269852128138506
# Step 2401 | Sliding Loss Window : 0.9952211497399891
# Step 2451 | Sliding Loss Window : 1.0115466257423171
# Step 2501 | Sliding Loss Window : 1.0152920031860067
# Step 2551 | Sliding Loss Window : 0.9869933088271093
# Step 2601 | Sliding Loss Window : 1.0002069671153526
# Step 2651 | Sliding Loss Window : 1.0387053821928303
# Step 2701 | Sliding Loss Window : 0.9842264189072851
# Step 2751 | Sliding Loss Window : 1.0362411120363284
# Step 2801 | Sliding Loss Window : 1.0311714550190525
# Step 2851 | Sliding Loss Window : 0.9560463980719863
# Step 2901 | Sliding Loss Window : 0.9347815374891202
# Step 2951 | Sliding Loss Window : 1.1420030920083222
# Step 3001 | Sliding Loss Window : 0.9730652663971311
# Step 3051 | Sliding Loss Window : 1.0143084295269187
# Step 3101 | Sliding Loss Window : 1.0113228297120231
# Step 3151 | Sliding Loss Window : 1.0728922306984905
# Step 3201 | Sliding Loss Window : 0.9871925552904675
# Step 3251 | Sliding Loss Window : 1.0302041464506977
# Step 3301 | Sliding Loss Window : 1.004194486234146
# Step 3351 | Sliding Loss Window : 1.0348616536608766
# Step 3401 | Sliding Loss Window : 0.9922894182439377
# Step 3451 | Sliding Loss Window : 0.9574464690077413
# Step 3501 | Sliding Loss Window : 1.009068277349998
# Step 3551 | Sliding Loss Window : 1.0148371752079277
# Step 3601 | Sliding Loss Window : 1.0139392831498042
# Step 3651 | Sliding Loss Window : 1.0577521718822152
# Step 3701 | Sliding Loss Window : 0.9608535862263473
# Step 3751 | Sliding Loss Window : 0.9901015599274251
# Step 3801 | Sliding Loss Window : 0.9769233769819924
# Step 3851 | Sliding Loss Window : 0.9916379065896257
# Step 3901 | Sliding Loss Window : 1.036983074909394
# Step 3951 | Sliding Loss Window : 1.062940545886597
# Step 4001 | Sliding Loss Window : 1.0061059676337731
# Step 4051 | Sliding Loss Window : 0.9939290361799132
# Step 4101 | Sliding Loss Window : 0.9391020020970826
# Step 4151 | Sliding Loss Window : 1.0013902585516237
# Step 4201 | Sliding Loss Window : 1.0295151123406177
# Step 4251 | Sliding Loss Window : 1.0388892368891767
# Step 4301 | Sliding Loss Window : 0.9346722956139512
# Step 4351 | Sliding Loss Window : 1.0378826341910412
# Step 4401 | Sliding Loss Window : 1.0419231275872947
# Step 4451 | Sliding Loss Window : 0.9624467482797091
# Step 4501 | Sliding Loss Window : 0.9472607388107651
# Step 4551 | Sliding Loss Window : 1.0992008859157285
# Step 4601 | Sliding Loss Window : 1.0074698026748024
# Step 4651 | Sliding Loss Window : 0.984286689454648
# Step 4701 | Sliding Loss Window : 1.023210356380633
# Step 4751 | Sliding Loss Window : 1.0346001930829305
# Step 4801 | Sliding Loss Window : 0.9994195343118085
# Step 4851 | Sliding Loss Window : 0.9917492775468701
# Step 4901 | Sliding Loss Window : 1.0190515755417844
# Step 4951 | Sliding Loss Window : 1.0105667163336272
# Step 5001 | Sliding Loss Window : 0.992239408012621
# Step 5051 | Sliding Loss Window : 0.9479726931829431
# Step 5101 | Sliding Loss Window : 0.9828718941634742
# Step 5151 | Sliding Loss Window : 0.9996095250600868
# Step 5201 | Sliding Loss Window : 0.9905757481846297
# Step 5251 | Sliding Loss Window : 1.0438277117653216
# Step 5301 | Sliding Loss Window : 0.9328389813134745
# Step 5351 | Sliding Loss Window : 0.9714716496310749
# Step 5401 | Sliding Loss Window : 0.956855786584162
# Step 5451 | Sliding Loss Window : 0.9962360153823494
# Step 5501 | Sliding Loss Window : 1.0241422503811828
# Step 5551 | Sliding Loss Window : 1.0714263763492056
# Step 5601 | Sliding Loss Window : 0.9869450621799909
# Step 5651 | Sliding Loss Window : 0.9955731993806757
# Step 5701 | Sliding Loss Window : 0.9762700462079789
# Step 5751 | Sliding Loss Window : 1.0095704787767774
# Step 5801 | Sliding Loss Window : 1.0222103408180248
# Step 5851 | Sliding Loss Window : 1.0409991526171463
# Step 5901 | Sliding Loss Window : 0.9360714087363423
# Step 5951 | Sliding Loss Window : 1.047178498948879
# Step 6001 | Sliding Loss Window : 1.043262711665594
# Step 6051 | Sliding Loss Window : 0.9689248104218082
# Step 6101 | Sliding Loss Window : 1.0121426556575785
# Step 6151 | Sliding Loss Window : 1.0356818439466338
# Step 6201 | Sliding Loss Window : 1.0101617105422516
# Step 6251 | Sliding Loss Window : 1.0008148367704792
# Step 6301 | Sliding Loss Window : 1.0012188806354765
# Step 6351 | Sliding Loss Window : 1.036765900305483
# Step 6401 | Sliding Loss Window : 1.007858254634151
# Step 6451 | Sliding Loss Window : 0.9873977811874838
# Step 6501 | Sliding Loss Window : 1.0239999818507164
# Step 6551 | Sliding Loss Window : 1.009703040255337
# Step 6601 | Sliding Loss Window : 0.9943835934569077
# Step 6651 | Sliding Loss Window : 0.9545840441274449
# Step 6701 | Sliding Loss Window : 0.982775828903801
# Step 6751 | Sliding Loss Window : 0.9980918470436483
# Step 6801 | Sliding Loss Window : 0.9806960257715798
# Step 6851 | Sliding Loss Window : 1.0297704848002502
# Step 6901 | Sliding Loss Window : 0.9158384332253842
# Step 6951 | Sliding Loss Window : 0.9769069939816194
# Step 7001 | Sliding Loss Window : 0.9574517047151467
# Step 7051 | Sliding Loss Window : 0.9840779064385444
# Step 7101 | Sliding Loss Window : 1.024396470336906
# Step 7151 | Sliding Loss Window : 1.0695995548462387
# Step 7201 | Sliding Loss Window : 0.9862161566641015
# Step 7251 | Sliding Loss Window : 0.9874061845449386
# Step 7301 | Sliding Loss Window : 0.9926624033157246
# Step 7351 | Sliding Loss Window : 1.0216278671549979
# Step 7401 | Sliding Loss Window : 1.037619782258111
# Step 7451 | Sliding Loss Window : 1.0318695102305966
# Step 7501 | Sliding Loss Window : 0.9238522784354478
# Step 7551 | Sliding Loss Window : 1.0503355556455225
# Step 7601 | Sliding Loss Window : 1.0471099868145297
# Step 7651 | Sliding Loss Window : 0.9634875479457484
# Step 7701 | Sliding Loss Window : 1.0187652826591784
# Step 7751 | Sliding Loss Window : 1.031508792803086
# Step 7801 | Sliding Loss Window : 1.0105662178314452
# Step 7851 | Sliding Loss Window : 0.9993775066472224
# Step 7901 | Sliding Loss Window : 1.0114255641227186
# Step 7951 | Sliding Loss Window : 1.0376895353110767
# Step 1 | Sliding Loss Window : 0.7197777615618773
# Step 51 | Sliding Loss Window : 1.11308947031456
# Step 101 | Sliding Loss Window : 1.173838873907225
# Step 151 | Sliding Loss Window : 0.9940646369947223
# Step 201 | Sliding Loss Window : 1.1860269019225869
# Step 251 | Sliding Loss Window : 1.0256203099998453
# Step 301 | Sliding Loss Window : 1.0519065591586167
# Step 351 | Sliding Loss Window : 1.0670154748517866
# Step 401 | Sliding Loss Window : 1.0474774093924228
# Step 451 | Sliding Loss Window : 1.0547132856127306
# Step 501 | Sliding Loss Window : 0.9756903495266036
# Step 551 | Sliding Loss Window : 1.0136595673994002
# Step 601 | Sliding Loss Window : 1.000729317141149
# Step 651 | Sliding Loss Window : 1.062692992147515
# Step 701 | Sliding Loss Window : 1.0240876244248114
# Step 751 | Sliding Loss Window : 1.1194190469385792
# Step 801 | Sliding Loss Window : 0.8727567960260026
# Step 851 | Sliding Loss Window : 1.104275315263976
# Step 901 | Sliding Loss Window : 1.0942854432460367
# Step 951 | Sliding Loss Window : 1.1007155352300382
# Step 1001 | Sliding Loss Window : 1.027285480433195
# Step 1051 | Sliding Loss Window : 1.0840612435103452
# Step 1101 | Sliding Loss Window : 1.0865081584539715
# Step 1151 | Sliding Loss Window : 1.0748788942477987
# Step 1201 | Sliding Loss Window : 1.0490150874117603
# Step 1251 | Sliding Loss Window : 1.0585910600584347
# Step 1301 | Sliding Loss Window : 0.9908405535146128
# Step 1351 | Sliding Loss Window : 1.0393705944930747
# Step 1401 | Sliding Loss Window : 1.0230611486891845
# Step 1451 | Sliding Loss Window : 0.9858872310749611
# Step 1501 | Sliding Loss Window : 1.0368805152670506
# Step 1551 | Sliding Loss Window : 0.9478410312295705
# Step 1601 | Sliding Loss Window : 1.057578906468775
# Step 1651 | Sliding Loss Window : 1.0179370011910345
# Step 1701 | Sliding Loss Window : 0.9891253612846416
# Step 1751 | Sliding Loss Window : 1.043554932862395
# Step 1801 | Sliding Loss Window : 1.0905938619554525
# Step 1851 | Sliding Loss Window : 0.9871542743339632
# Step 1901 | Sliding Loss Window : 1.009746332857374
# Step 1951 | Sliding Loss Window : 1.034526722226723
# Step 2001 | Sliding Loss Window : 1.0914772852181855
# Step 2051 | Sliding Loss Window : 1.0006891090370418
# Step 2101 | Sliding Loss Window : 0.9782528250331431
# Step 2151 | Sliding Loss Window : 1.0333691294025886
# Step 2201 | Sliding Loss Window : 0.9911614647499314
# Step 2251 | Sliding Loss Window : 1.0506422308432581
# Step 2301 | Sliding Loss Window : 1.024965795328737
# Step 2351 | Sliding Loss Window : 1.0903922014160943
# Step 2401 | Sliding Loss Window : 0.8848578509237516
# Step 2451 | Sliding Loss Window : 1.1216776159024888
# Step 2501 | Sliding Loss Window : 1.0777934212131273
# Step 2551 | Sliding Loss Window : 1.0681156413387967
# Step 2601 | Sliding Loss Window : 1.056709421415558
# Step 2651 | Sliding Loss Window : 1.088386156344708
# Step 2701 | Sliding Loss Window : 1.0507820291105667
# Step 2751 | Sliding Loss Window : 1.0529039443809682
# Step 2801 | Sliding Loss Window : 1.0414805018201212
# Step 2851 | Sliding Loss Window : 1.0233399630773738
# Step 2901 | Sliding Loss Window : 0.9724032683545896
# Step 2951 | Sliding Loss Window : 1.0326902839879577
# Step 3001 | Sliding Loss Window : 0.9983605581810788
# Step 3051 | Sliding Loss Window : 1.0474235061856174
# Step 3101 | Sliding Loss Window : 1.0469755688944995
# Step 3151 | Sliding Loss Window : 1.0598576321631554
# Step 3201 | Sliding Loss Window : 1.0257292633243895
# Step 3251 | Sliding Loss Window : 1.0508545528749562
# Step 3301 | Sliding Loss Window : 0.9889402008061735
# Step 3351 | Sliding Loss Window : 0.9981330305113062
# Step 3401 | Sliding Loss Window : 1.0481754767311493
# Step 3451 | Sliding Loss Window : 1.0202130163244574
# Step 3501 | Sliding Loss Window : 1.0172356797133517
# Step 3551 | Sliding Loss Window : 0.9968379732982119
# Step 3601 | Sliding Loss Window : 1.0053693012837501
# Step 3651 | Sliding Loss Window : 1.0036435428969455
# Step 3701 | Sliding Loss Window : 1.0077550356159855
# Step 3751 | Sliding Loss Window : 1.01808602887333
# Step 3801 | Sliding Loss Window : 0.9760373616132673
# Step 3851 | Sliding Loss Window : 1.0350752148771984
# Step 3901 | Sliding Loss Window : 0.9928540414769388
# Step 3951 | Sliding Loss Window : 1.045010068263843
# Step 4001 | Sliding Loss Window : 0.9978207945457414
# Step 4051 | Sliding Loss Window : 1.0669738131127773
# Step 4101 | Sliding Loss Window : 1.048540467925596
# Step 4151 | Sliding Loss Window : 1.0015252600920566
# Step 4201 | Sliding Loss Window : 1.052460154198767
# Step 4251 | Sliding Loss Window : 1.03957588844112
# Step 4301 | Sliding Loss Window : 1.0146650209027306
# Step 4351 | Sliding Loss Window : 1.0307353602767428
# Step 4401 | Sliding Loss Window : 1.030692916028113
# Step 4451 | Sliding Loss Window : 1.0147400835573763
# Step 4501 | Sliding Loss Window : 0.9831944792689253
# Step 4551 | Sliding Loss Window : 0.9998672936609607
# Step 4601 | Sliding Loss Window : 0.9869966001826446
# Step 4651 | Sliding Loss Window : 1.0536238307780394
# Step 4701 | Sliding Loss Window : 1.0257612549427062
# Step 4751 | Sliding Loss Window : 1.0338763365346813
# Step 4801 | Sliding Loss Window : 1.0129368589004764
# Step 4851 | Sliding Loss Window : 1.044160648836927
# Step 4901 | Sliding Loss Window : 0.9884179672579164
# Step 4951 | Sliding Loss Window : 1.0013355408881022
# Step 5001 | Sliding Loss Window : 1.030671332779132
# Step 5051 | Sliding Loss Window : 1.0127343292065094
# Step 5101 | Sliding Loss Window : 1.0098351027652854
# Step 5151 | Sliding Loss Window : 0.9950314813462202
# Step 5201 | Sliding Loss Window : 1.002346923352351
# Step 5251 | Sliding Loss Window : 1.015472360097722
# Step 5301 | Sliding Loss Window : 1.0102431611733034
# Step 5351 | Sliding Loss Window : 1.0171257281166302
# Step 5401 | Sliding Loss Window : 0.9944882286424768
# Step 5451 | Sliding Loss Window : 1.0125083009926101
# Step 5501 | Sliding Loss Window : 0.9792819154895933
# Step 5551 | Sliding Loss Window : 1.05216462961031
# Step 5601 | Sliding Loss Window : 1.0005635242516084
# Step 5651 | Sliding Loss Window : 1.0601312630001936
# Step 5701 | Sliding Loss Window : 1.0505787739894419
# Step 5751 | Sliding Loss Window : 0.9884822554615548
# Step 5801 | Sliding Loss Window : 1.0309022901371763
# Step 5851 | Sliding Loss Window : 1.036354615746834
# Step 5901 | Sliding Loss Window : 1.0023732900901798
# Step 5951 | Sliding Loss Window : 1.0399873929835584
# Step 6001 | Sliding Loss Window : 1.020905274930738
# Step 6051 | Sliding Loss Window : 1.012305713460972
# Step 6101 | Sliding Loss Window : 0.9897031659806537
# Step 6151 | Sliding Loss Window : 0.9994052888577001
# Step 6201 | Sliding Loss Window : 0.988628736161977
# Step 6251 | Sliding Loss Window : 1.0434646693406981
# Step 6301 | Sliding Loss Window : 1.011860180545632
# Step 6351 | Sliding Loss Window : 1.0204015142330325
# Step 6401 | Sliding Loss Window : 1.0198817101343765
# Step 6451 | Sliding Loss Window : 1.0171819695737825
# Step 6501 | Sliding Loss Window : 0.999444758421689
# Step 6551 | Sliding Loss Window : 0.9954488218882187
# Step 6601 | Sliding Loss Window : 1.01740156646392
# Step 6651 | Sliding Loss Window : 1.0047620962286472
# Step 6701 | Sliding Loss Window : 1.0100570214689022
# Step 6751 | Sliding Loss Window : 1.0036489017153394
# Step 6801 | Sliding Loss Window : 1.0113206970056376
# Step 6851 | Sliding Loss Window : 1.0295560397773378
# Step 6901 | Sliding Loss Window : 1.0115097366304304
# Step 6951 | Sliding Loss Window : 0.9995518240255528
# Step 7001 | Sliding Loss Window : 0.995895397636983
# Step 7051 | Sliding Loss Window : 0.9974024046987044
# Step 7101 | Sliding Loss Window : 0.9367951851602505
# Step 7151 | Sliding Loss Window : 1.0700056181435924
# Step 7201 | Sliding Loss Window : 0.9409866266809194
# Step 7251 | Sliding Loss Window : 1.053974445612508
# Step 7301 | Sliding Loss Window : 1.0347087130073012
# Step 7351 | Sliding Loss Window : 0.9868710980542598
# Step 7401 | Sliding Loss Window : 0.9752454295329085
# Step 7451 | Sliding Loss Window : 1.081189155660208
# Step 7501 | Sliding Loss Window : 0.9920709711986642
# Step 7551 | Sliding Loss Window : 1.0336986002694555
# Step 7601 | Sliding Loss Window : 1.0209385330098726
# Step 7651 | Sliding Loss Window : 1.0068764737893448
# Step 7701 | Sliding Loss Window : 0.9938803537590717
# Step 7751 | Sliding Loss Window : 1.0044954330205211
# Step 7801 | Sliding Loss Window : 0.9914544435222088
# Step 7851 | Sliding Loss Window : 1.0385984851971843
# Step 7901 | Sliding Loss Window : 1.0057200832262854
# Step 7951 | Sliding Loss Window : 1.0090138473915458
# Step 1 | Sliding Loss Window : 0.2654006560619894
# Step 51 | Sliding Loss Window : 1.0646323221473184
# Step 101 | Sliding Loss Window : 1.0804403367870774
# Step 151 | Sliding Loss Window : 0.9729058373938494
# Step 201 | Sliding Loss Window : 1.2720486373545559
# Step 251 | Sliding Loss Window : 1.1243770924273127
# Step 301 | Sliding Loss Window : 1.1004343172896212
# Step 351 | Sliding Loss Window : 1.0942265167887526
# Step 401 | Sliding Loss Window : 1.1768004741022622
# Step 451 | Sliding Loss Window : 1.1764209942977597
# Step 501 | Sliding Loss Window : 1.0284519733686839
# Step 551 | Sliding Loss Window : 0.9881086293993792
# Step 601 | Sliding Loss Window : 1.0374222145960683
# Step 651 | Sliding Loss Window : 1.0718248884832642
# Step 701 | Sliding Loss Window : 0.9910714501810775
# Step 751 | Sliding Loss Window : 1.0770073560831357
# Step 801 | Sliding Loss Window : 0.9684601653055779
# Step 851 | Sliding Loss Window : 1.0163838677054102
# Step 901 | Sliding Loss Window : 1.051234342539142
# Step 951 | Sliding Loss Window : 1.0443679041785938
# Step 1001 | Sliding Loss Window : 1.0089638135895393
# Step 1051 | Sliding Loss Window : 0.9715991532378119
# Step 1101 | Sliding Loss Window : 1.0690245965042522
# Step 1151 | Sliding Loss Window : 1.080133085198221
# Step 1201 | Sliding Loss Window : 0.9943565583588476
# Step 1251 | Sliding Loss Window : 1.003232529970289
# Step 1301 | Sliding Loss Window : 1.0720592320421318
# Step 1351 | Sliding Loss Window : 1.007050926215569
# Step 1401 | Sliding Loss Window : 1.0010567854150976
# Step 1451 | Sliding Loss Window : 0.9800690496121076
# Step 1501 | Sliding Loss Window : 0.9600486593413464
# Step 1551 | Sliding Loss Window : 1.0717310286171533
# Step 1601 | Sliding Loss Window : 1.0100220096660204
# Step 1651 | Sliding Loss Window : 0.9408280802744087
# Step 1701 | Sliding Loss Window : 1.0407090051846675
# Step 1751 | Sliding Loss Window : 1.0347891827049092
# Step 1801 | Sliding Loss Window : 1.0806125897099201
# Step 1851 | Sliding Loss Window : 1.0596803844301403
# Step 1901 | Sliding Loss Window : 0.9986448018204951
# Step 1951 | Sliding Loss Window : 1.0950081745826792
# Step 2001 | Sliding Loss Window : 0.9591448491329867
# Step 2051 | Sliding Loss Window : 1.0142446105160703
# Step 2101 | Sliding Loss Window : 1.0018436567025306
# Step 2151 | Sliding Loss Window : 0.8971597945666484
# Step 2201 | Sliding Loss Window : 1.0136541908092602
# Step 2251 | Sliding Loss Window : 0.9784367766968372
# Step 2301 | Sliding Loss Window : 0.8737417988223645
# Step 2351 | Sliding Loss Window : 0.9789292071847372
# Step 2401 | Sliding Loss Window : 1.1486353376866163
# Step 2451 | Sliding Loss Window : 1.0958151910374432
# Step 2501 | Sliding Loss Window : 1.006595272197831
# Step 2551 | Sliding Loss Window : 1.0510631185123058
# Step 2601 | Sliding Loss Window : 1.0419819923894007
# Step 2651 | Sliding Loss Window : 1.020598387035625
# Step 2701 | Sliding Loss Window : 1.0274703386804973
# Step 2751 | Sliding Loss Window : 1.0197490083993568
# Step 2801 | Sliding Loss Window : 0.990232566449709
# Step 2851 | Sliding Loss Window : 0.9861742509515081
# Step 2901 | Sliding Loss Window : 1.042265685410306
# Step 2951 | Sliding Loss Window : 1.048116167959727
# Step 3001 | Sliding Loss Window : 1.0399956371928603
# Step 3051 | Sliding Loss Window : 0.9735772010090763
# Step 3101 | Sliding Loss Window : 0.9867418261925353
# Step 3151 | Sliding Loss Window : 1.0540136060036547
# Step 3201 | Sliding Loss Window : 0.9645198224878895
# Step 3251 | Sliding Loss Window : 1.0105966705173683
# Step 3301 | Sliding Loss Window : 1.044951974750343
# Step 3351 | Sliding Loss Window : 1.0060700475143505
# Step 3401 | Sliding Loss Window : 1.0603573493867657
# Step 3451 | Sliding Loss Window : 1.0288392374771123
# Step 3501 | Sliding Loss Window : 1.024721480920336
# Step 3551 | Sliding Loss Window : 1.0752250730373094
# Step 3601 | Sliding Loss Window : 0.8648392591452256
# Step 3651 | Sliding Loss Window : 1.049587122635641
# Step 3701 | Sliding Loss Window : 0.9667530615526451
# Step 3751 | Sliding Loss Window : 0.9202923977081074
# Step 3801 | Sliding Loss Window : 1.0703756012302224
# Step 3851 | Sliding Loss Window : 0.9847269519295105
# Step 3901 | Sliding Loss Window : 0.9079475642445531
# Step 3951 | Sliding Loss Window : 0.9906036461787702
# Step 4001 | Sliding Loss Window : 1.0907463319378194
# Step 4051 | Sliding Loss Window : 1.0621272214279456
# Step 4101 | Sliding Loss Window : 0.9972574869196299
# Step 4151 | Sliding Loss Window : 1.0264642053612414
# Step 4201 | Sliding Loss Window : 1.0454263518889066
# Step 4251 | Sliding Loss Window : 1.0178289582378925
# Step 4301 | Sliding Loss Window : 1.0320534916478679
# Step 4351 | Sliding Loss Window : 0.9908665115203462
# Step 4401 | Sliding Loss Window : 0.983873348264537
# Step 4451 | Sliding Loss Window : 0.9702113363680147
# Step 4501 | Sliding Loss Window : 1.0172298822386205
# Step 4551 | Sliding Loss Window : 1.0293449459631476
# Step 4601 | Sliding Loss Window : 1.0483253529078036
# Step 4651 | Sliding Loss Window : 0.961241623519992
# Step 4701 | Sliding Loss Window : 1.0059306588078512
# Step 4751 | Sliding Loss Window : 1.0364028862461483
# Step 4801 | Sliding Loss Window : 0.9929042351130255
# Step 4851 | Sliding Loss Window : 0.9909024677928748
# Step 4901 | Sliding Loss Window : 1.0571085525137762
# Step 4951 | Sliding Loss Window : 0.9948071831484324
# Step 5001 | Sliding Loss Window : 1.0441402804156612
# Step 5051 | Sliding Loss Window : 1.028579120191944
# Step 5101 | Sliding Loss Window : 1.0242579984773634
# Step 5151 | Sliding Loss Window : 1.0672829279272236
# Step 5201 | Sliding Loss Window : 0.9234771354153928
# Step 5251 | Sliding Loss Window : 1.0506560754565784
# Step 5301 | Sliding Loss Window : 0.9789194988440123
# Step 5351 | Sliding Loss Window : 0.9526434723608896
# Step 5401 | Sliding Loss Window : 1.0650516588828076
# Step 5451 | Sliding Loss Window : 0.9856685788768165
# Step 5501 | Sliding Loss Window : 0.9286450505420168
# Step 5551 | Sliding Loss Window : 1.0344338994394213
# Step 5601 | Sliding Loss Window : 1.0639706032397909
# Step 5651 | Sliding Loss Window : 1.040597618734268
# Step 5701 | Sliding Loss Window : 0.9442927983104018
# Step 5751 | Sliding Loss Window : 1.0607157129514868
# Step 5801 | Sliding Loss Window : 1.0250199886707494
# Step 5851 | Sliding Loss Window : 0.9947747624132315
# Step 5901 | Sliding Loss Window : 1.0158381253363407
# Step 5951 | Sliding Loss Window : 1.0128206329564484
# Step 6001 | Sliding Loss Window : 0.9585397209773845
# Step 6051 | Sliding Loss Window : 0.9417205540717762
# Step 6101 | Sliding Loss Window : 1.01845980966552
# Step 6151 | Sliding Loss Window : 0.9886311721944864
# Step 6201 | Sliding Loss Window : 1.0281026991584223
# Step 6251 | Sliding Loss Window : 0.9827272913568997
# Step 6301 | Sliding Loss Window : 0.9878194639731795
# Step 6351 | Sliding Loss Window : 1.017261615716842
# Step 6401 | Sliding Loss Window : 0.9946833902246258
# Step 6451 | Sliding Loss Window : 0.9680391736631004
# Step 6501 | Sliding Loss Window : 1.0534833962063117
# Step 6551 | Sliding Loss Window : 1.006267314278112
# Step 6601 | Sliding Loss Window : 1.0176440021531092
# Step 6651 | Sliding Loss Window : 1.0443942312408654
# Step 6701 | Sliding Loss Window : 1.0229300454459265
# Step 6751 | Sliding Loss Window : 1.069098461498036
# Step 6801 | Sliding Loss Window : 0.9973185102959471
# Step 6851 | Sliding Loss Window : 1.0445872207444538
# Step 6901 | Sliding Loss Window : 1.001556436297475
# Step 6951 | Sliding Loss Window : 0.9542977497210916
# Step 7001 | Sliding Loss Window : 1.0303442598061499
# Step 7051 | Sliding Loss Window : 0.9768643873408636
# Step 7101 | Sliding Loss Window : 0.918238738027396
# Step 7151 | Sliding Loss Window : 1.0707267088668566
# Step 7201 | Sliding Loss Window : 1.0644809196823528
# Step 7251 | Sliding Loss Window : 1.032584663171164
# Step 7301 | Sliding Loss Window : 0.9483143010557447
# Step 7351 | Sliding Loss Window : 1.0579948808142825
# Step 7401 | Sliding Loss Window : 0.9952672400100616
# Step 7451 | Sliding Loss Window : 1.0135046765923637
# Step 7501 | Sliding Loss Window : 1.0021452631736332
# Step 7551 | Sliding Loss Window : 1.0610116420177862
# Step 7601 | Sliding Loss Window : 0.9683023203011847
# Step 7651 | Sliding Loss Window : 0.9887350343736762
# Step 7701 | Sliding Loss Window : 1.0039898652876318
# Step 7751 | Sliding Loss Window : 1.0197362558082568
# Step 7801 | Sliding Loss Window : 0.9623678405400728
# Step 7851 | Sliding Loss Window : 1.028506746583117
# Step 7901 | Sliding Loss Window : 0.9470971545803066
# Step 7951 | Sliding Loss Window : 1.037714118466491
# 0.5675 1.0034125423431397 [239641 213135  20107 176108 264213]
# Step 1 | Sliding Loss Window : 1.3857134510846294
# Step 51 | Sliding Loss Window : 0.997558862494838
# Step 101 | Sliding Loss Window : 0.9877656164545111
# Step 151 | Sliding Loss Window : 1.002959009163864
# Step 201 | Sliding Loss Window : 1.0220304609431268
# Step 251 | Sliding Loss Window : 1.0852187657530035
# Step 301 | Sliding Loss Window : 1.0768388159819553
# Step 351 | Sliding Loss Window : 0.9862154800050028
# Step 401 | Sliding Loss Window : 1.0885568052306087
# Step 451 | Sliding Loss Window : 0.9537100032161053
# Step 501 | Sliding Loss Window : 1.0181218291528178
# Step 551 | Sliding Loss Window : 1.0718194364484186
# Step 601 | Sliding Loss Window : 0.9776976976942541
# Step 651 | Sliding Loss Window : 1.0345602712934039
# Step 701 | Sliding Loss Window : 0.9980024064691044
# Step 751 | Sliding Loss Window : 0.9985597703443806
# Step 801 | Sliding Loss Window : 1.002628802012225
# Step 851 | Sliding Loss Window : 1.0361347439145134
# Step 901 | Sliding Loss Window : 1.01466142772399
# Step 951 | Sliding Loss Window : 1.0758957859584135
# Step 1001 | Sliding Loss Window : 0.993278645444501
# Step 1051 | Sliding Loss Window : 1.0423874099535446
# Step 1101 | Sliding Loss Window : 1.056938482291592
# Step 1151 | Sliding Loss Window : 0.9798590733263878
# Step 1201 | Sliding Loss Window : 0.9867164828013361
# Step 1251 | Sliding Loss Window : 1.0639695250968453
# Step 1301 | Sliding Loss Window : 1.0629532313893477
# Step 1351 | Sliding Loss Window : 1.0181599037939528
# Step 1401 | Sliding Loss Window : 1.0197363722304322
# Step 1451 | Sliding Loss Window : 1.005062733086166
# Step 1501 | Sliding Loss Window : 0.9849665919655755
# Step 1551 | Sliding Loss Window : 1.0042836587607509
# Step 1601 | Sliding Loss Window : 0.944175877044012
# Step 1651 | Sliding Loss Window : 0.9866494269349375
# Step 1701 | Sliding Loss Window : 0.9530734953959921
# Step 1751 | Sliding Loss Window : 0.9614301612224451
# Step 1801 | Sliding Loss Window : 0.9732533909861465
# Step 1851 | Sliding Loss Window : 1.0876676536666356
# Step 1901 | Sliding Loss Window : 1.0425366517696155
# Step 1951 | Sliding Loss Window : 0.9684215783041046
# Step 2001 | Sliding Loss Window : 1.0783247147772035
# Step 2051 | Sliding Loss Window : 0.9841846852349444
# Step 2101 | Sliding Loss Window : 1.033414158110461
# Step 2151 | Sliding Loss Window : 1.0711386464421846
# Step 2201 | Sliding Loss Window : 0.9746736969434114
# Step 2251 | Sliding Loss Window : 0.98776220564474
# Step 2301 | Sliding Loss Window : 0.9998651991963291
# Step 2351 | Sliding Loss Window : 1.0206825721556556
# Step 2401 | Sliding Loss Window : 0.9524638724213852
# Step 2451 | Sliding Loss Window : 1.0356321996841749
# Step 2501 | Sliding Loss Window : 1.0182328413344386
# Step 2551 | Sliding Loss Window : 1.1006861271223103
# Step 2601 | Sliding Loss Window : 0.9895994890646872
# Step 2651 | Sliding Loss Window : 1.030399195324096
# Step 2701 | Sliding Loss Window : 1.0264397243489967
# Step 2751 | Sliding Loss Window : 1.0155841690012115
# Step 2801 | Sliding Loss Window : 0.965051739569104
# Step 2851 | Sliding Loss Window : 0.9792106594185428
# Step 2901 | Sliding Loss Window : 1.0355018973963468
# Step 2951 | Sliding Loss Window : 0.9938162067408736
# ...
# Step 1051 | Sliding Loss Window : 1.0021453499997997
# Step 1101 | Sliding Loss Window : 0.9236600984697635
# Step 1151 | Sliding Loss Window : 0.9990983012835332
# Step 1201 | Sliding Loss Window : 1.0354832040575874
# Step 1251 | Sliding Loss Window : 1.0155165497734313
# Step 1301 | Sliding Loss Window : 1.0734739889166631
# Step 1351 | Sliding Loss Window : 1.0211636757804314
# Step 1401 | Sliding Loss Window : 1.0605745502305552
# Step 1451 | Sliding Loss Window : 0.9515452607882214
# Step 1501 | Sliding Loss Window : 1.0439020546256166
# Step 1551 | Sliding Loss Window : 0.9443833396007484
# Step 1601 | Sliding Loss Window : 1.0418521599748833
# Step 1651 | Sliding Loss Window : 1.0381017783529527
# Step 1701 | Sliding Loss Window : 0.9490548152478299
# Step 1751 | Sliding Loss Window : 1.0323406178670385
# Step 1801 | Sliding Loss Window : 0.9936259230239256
# Step 1851 | Sliding Loss Window : 1.0622296201606725
# Step 1901 | Sliding Loss Window : 0.8652957433142034
# Step 1951 | Sliding Loss Window : 1.0269307211181926
# Step 2001 | Sliding Loss Window : 1.0497442638183412
# Step 2051 | Sliding Loss Window : 1.0827440197601719
# Step 2101 | Sliding Loss Window : 1.0095223387106325
# Step 2151 | Sliding Loss Window : 1.0853278183439858
# Step 2201 | Sliding Loss Window : 0.9387970732085126
# Step 2251 | Sliding Loss Window : 0.9979589608989753
# Step 2301 | Sliding Loss Window : 1.0512502172459204
# Step 2351 | Sliding Loss Window : 1.0020198451150133
# Step 2401 | Sliding Loss Window : 1.0221829804896563
# Step 2451 | Sliding Loss Window : 0.9570693662589008
# Step 2501 | Sliding Loss Window : 1.0210485610097177
# Step 2551 | Sliding Loss Window : 1.0085648598590524
# Step 2601 | Sliding Loss Window : 0.9975392906549365
# Step 2651 | Sliding Loss Window : 1.0485434050874454
# Step 2701 | Sliding Loss Window : 0.9805624525181369
# Step 2751 | Sliding Loss Window : 0.9657570479640004
# Step 2801 | Sliding Loss Window : 0.9950227384606167
# Step 2851 | Sliding Loss Window : 0.9550146365049517
# Step 2901 | Sliding Loss Window : 1.080260340920378
# Step 2951 | Sliding Loss Window : 0.9952389871389089
# Step 3001 | Sliding Loss Window : 1.0614705730266818
# Step 3051 | Sliding Loss Window : 0.9598580939504971
# Step 3101 | Sliding Loss Window : 1.0569406694557881
# Step 3151 | Sliding Loss Window : 0.885395932027587
# Step 3201 | Sliding Loss Window : 1.0919534132658002
# Step 3251 | Sliding Loss Window : 1.0837018848608155
# Step 3301 | Sliding Loss Window : 0.9407364687786687
# Step 3351 | Sliding Loss Window : 1.0253684785783148
# Step 3401 | Sliding Loss Window : 0.9939429312791382
# Step 3451 | Sliding Loss Window : 1.0414118733492124
# Step 3501 | Sliding Loss Window : 0.9041193559119872
# Step 3551 | Sliding Loss Window : 0.9949782411047587
# Step 3601 | Sliding Loss Window : 1.0247970077772974
# Step 3651 | Sliding Loss Window : 1.11493772616059
# Step 3701 | Sliding Loss Window : 1.0110823932289557
# Step 3751 | Sliding Loss Window : 1.1031158804830237
# Step 3801 | Sliding Loss Window : 0.9377953183840932
# Step 3851 | Sliding Loss Window : 0.9709151592850866
# Step 3901 | Sliding Loss Window : 1.1151508205235245
# Step 3951 | Sliding Loss Window : 0.9045080816743523
# Step 4001 | Sliding Loss Window : 1.1011486152267287
# Step 4051 | Sliding Loss Window : 0.9530300947763329
# Step 4101 | Sliding Loss Window : 0.9075494747690205
# Step 4151 | Sliding Loss Window : 0.9495433565058766
# Step 4201 | Sliding Loss Window : 0.9335433680072072
# Step 4251 | Sliding Loss Window : 1.0636611303107641
# Step 4301 | Sliding Loss Window : 1.0044983714273448
# Step 4351 | Sliding Loss Window : 0.94310885723398
# Step 4401 | Sliding Loss Window : 1.0044384660437025
# Step 4451 | Sliding Loss Window : 0.9133144068249905
# Step 4501 | Sliding Loss Window : 1.0527329071171463
# Step 4551 | Sliding Loss Window : 0.9627919472745451
# Step 4601 | Sliding Loss Window : 1.052972081580437
# Step 4651 | Sliding Loss Window : 0.9885134960103947
# Step 4701 | Sliding Loss Window : 1.0591531386578377
# Step 4751 | Sliding Loss Window : 0.8864322874751547
# Step 4801 | Sliding Loss Window : 1.111966128555486
# Step 4851 | Sliding Loss Window : 1.0339401374488324
# Step 4901 | Sliding Loss Window : 0.9638145629817779
# Step 4951 | Sliding Loss Window : 1.0213702092419794
# Step 5001 | Sliding Loss Window : 0.9736641425269893
# Step 5051 | Sliding Loss Window : 1.0172369499632883
# Step 5101 | Sliding Loss Window : 0.9732025567794607
# Step 5151 | Sliding Loss Window : 1.0366620673410603
# Step 5201 | Sliding Loss Window : 1.01147888608166
# Step 5251 | Sliding Loss Window : 1.0295455448392947
# Step 5301 | Sliding Loss Window : 0.9948954631285438
# Step 5351 | Sliding Loss Window : 1.046123577815302
# Step 5401 | Sliding Loss Window : 0.9784162163499317
# Step 5451 | Sliding Loss Window : 0.9645925168676424
# Step 5501 | Sliding Loss Window : 1.057520200589583
# Step 5551 | Sliding Loss Window : 0.9018280939641459
# Step 5601 | Sliding Loss Window : 1.0817936713860992
# Step 5651 | Sliding Loss Window : 0.9289090839445328
# Step 5701 | Sliding Loss Window : 0.9662621688415323
# Step 5751 | Sliding Loss Window : 0.9659411265374956
# Step 5801 | Sliding Loss Window : 0.977038862681944
# Step 5851 | Sliding Loss Window : 1.0216462139037659
# Step 5901 | Sliding Loss Window : 0.9321306133780066
# Step 5951 | Sliding Loss Window : 0.9556580508859989
# Step 6001 | Sliding Loss Window : 1.0036018997069023
# Step 6051 | Sliding Loss Window : 0.9450019343840813
# Step 6101 | Sliding Loss Window : 1.0314022149978475
# Step 6151 | Sliding Loss Window : 0.9638441402910108
# Step 6201 | Sliding Loss Window : 1.0304210767590443
# Step 6251 | Sliding Loss Window : 0.9619956730329366
# Step 6301 | Sliding Loss Window : 1.0571447475089066
# Step 6351 | Sliding Loss Window : 0.9214251718964719
# Step 6401 | Sliding Loss Window : 1.105487135310414
# Step 6451 | Sliding Loss Window : 1.0054000192885022
# Step 6501 | Sliding Loss Window : 0.9899917513290661
# Step 6551 | Sliding Loss Window : 1.0178260578004668
# Step 6601 | Sliding Loss Window : 1.014818295952895
# Step 6651 | Sliding Loss Window : 0.9786395288004747
# Step 6701 | Sliding Loss Window : 0.97875385552379
# Step 6751 | Sliding Loss Window : 1.0274764689097349
# Step 6801 | Sliding Loss Window : 1.0017303190922717
# Step 6851 | Sliding Loss Window : 1.0239590340117704
# Step 6901 | Sliding Loss Window : 0.9761246205104566
# Step 6951 | Sliding Loss Window : 1.0397440769570008
# Step 7001 | Sliding Loss Window : 0.978834041101528
# Step 7051 | Sliding Loss Window : 0.9601926871107588
# Step 7101 | Sliding Loss Window : 1.0394205040207607
# Step 7151 | Sliding Loss Window : 0.8976643537490189
# Step 7201 | Sliding Loss Window : 1.0697917550702625
# Step 7251 | Sliding Loss Window : 0.9420409570914462
# Step 7301 | Sliding Loss Window : 0.9680716035683343
# Step 7351 | Sliding Loss Window : 0.952928501431057
# Step 7401 | Sliding Loss Window : 0.9706833787646513
# Step 7451 | Sliding Loss Window : 1.0177268007657148
# Step 7501 | Sliding Loss Window : 0.9333204542641895
# Step 7551 | Sliding Loss Window : 0.9750838513299296
# Step 7601 | Sliding Loss Window : 0.9975604416656298
# Step 7651 | Sliding Loss Window : 0.9573996347530109
# Step 7701 | Sliding Loss Window : 1.0336814391107432
# Step 7751 | Sliding Loss Window : 0.9650580042659874
# Step 7801 | Sliding Loss Window : 1.0283192935029644
# Step 7851 | Sliding Loss Window : 0.9626699980478363
# Step 7901 | Sliding Loss Window : 1.0609231124823024
# Step 7951 | Sliding Loss Window : 0.9299564846262359
# Step 1 | Sliding Loss Window : 0.4761971572432698
# Step 51 | Sliding Loss Window : 1.1699497018163674
# Step 101 | Sliding Loss Window : 1.1302758917295872
# Step 151 | Sliding Loss Window : 1.0291573643126872
# Step 201 | Sliding Loss Window : 1.0733054858798292
# Step 251 | Sliding Loss Window : 1.0610632867114536
# Step 301 | Sliding Loss Window : 1.0460903687445675
# Step 351 | Sliding Loss Window : 1.0020421083880706
# Step 401 | Sliding Loss Window : 1.0262362698477336
# Step 451 | Sliding Loss Window : 1.016300969622905
# Step 501 | Sliding Loss Window : 1.0251973114800061
# Step 551 | Sliding Loss Window : 1.0176408607520788
# Step 601 | Sliding Loss Window : 1.0174630981125456
# Step 651 | Sliding Loss Window : 1.0240291016976841
# Step 701 | Sliding Loss Window : 1.026161059126248
# Step 751 | Sliding Loss Window : 0.9680990305931231
# Step 801 | Sliding Loss Window : 1.0334953120265673
# Step 851 | Sliding Loss Window : 1.0228021221890358
# Step 901 | Sliding Loss Window : 1.0119417078944621
# Step 951 | Sliding Loss Window : 0.9658006796811605
# Step 1001 | Sliding Loss Window : 0.9947975106003409
# Step 1051 | Sliding Loss Window : 1.0397198084601236
# Step 1101 | Sliding Loss Window : 0.9930156618061067
# Step 1151 | Sliding Loss Window : 1.032406981513397
# Step 1201 | Sliding Loss Window : 1.0048382748087945
# Step 1251 | Sliding Loss Window : 1.0419870320922173
# Step 1301 | Sliding Loss Window : 0.9952268076616438
# Step 1351 | Sliding Loss Window : 1.0084445087393867
# Step 1401 | Sliding Loss Window : 1.0272164740941536
# Step 1451 | Sliding Loss Window : 0.9995762340954013
# Step 1501 | Sliding Loss Window : 1.007160311149453
# Step 1551 | Sliding Loss Window : 0.9743660510851853
# Step 1601 | Sliding Loss Window : 1.0080657960103125
# Step 1651 | Sliding Loss Window : 0.9808758842600669
# Step 1701 | Sliding Loss Window : 1.021983726144624
# Step 1751 | Sliding Loss Window : 1.0049418723569217
# Step 1801 | Sliding Loss Window : 0.9374081519445397
# Step 1851 | Sliding Loss Window : 1.0795038964834283
# Step 1901 | Sliding Loss Window : 1.034104314324667
# Step 1951 | Sliding Loss Window : 0.984752904124041
# Step 2001 | Sliding Loss Window : 1.0331113443874822
# Step 2051 | Sliding Loss Window : 1.0228617197552963
# Step 2101 | Sliding Loss Window : 0.9934422773261856
# Step 2151 | Sliding Loss Window : 0.9795411047710904
# Step 2201 | Sliding Loss Window : 0.9510216750455396
# Step 2251 | Sliding Loss Window : 1.0081656954793203
# Step 2301 | Sliding Loss Window : 0.9719365079340717
# Step 2351 | Sliding Loss Window : 0.9927086796095483
# Step 2401 | Sliding Loss Window : 0.8984451328910916
# Step 2451 | Sliding Loss Window : 1.0706556949384378
# Step 2501 | Sliding Loss Window : 1.00517768061146
# Step 2551 | Sliding Loss Window : 0.9791286015535531
# Step 2601 | Sliding Loss Window : 0.9833535688704366
# Step 2651 | Sliding Loss Window : 1.0381888560457955
# Step 2701 | Sliding Loss Window : 0.9356151095301365
# Step 2751 | Sliding Loss Window : 1.0573577773201734
# Step 2801 | Sliding Loss Window : 0.8959280336760835
# Step 2851 | Sliding Loss Window : 1.0684484182010328
# Step 2901 | Sliding Loss Window : 0.9929185587116397
# Step 2951 | Sliding Loss Window : 1.053047527245421
# Step 3001 | Sliding Loss Window : 1.0143130381459589
# Step 3051 | Sliding Loss Window : 1.0521676199878813
# Step 3101 | Sliding Loss Window : 1.0025753129764003
# Step 3151 | Sliding Loss Window : 0.9894955970429813
# Step 3201 | Sliding Loss Window : 1.004282306472053
# Step 3251 | Sliding Loss Window : 0.9798659711593419
# Step 3301 | Sliding Loss Window : 1.0585815767174787
# Step 3351 | Sliding Loss Window : 1.0020669140564793
# Step 3401 | Sliding Loss Window : 0.9593675849741536
# Step 3451 | Sliding Loss Window : 1.0502256611463894
# Step 3501 | Sliding Loss Window : 0.9609404556033071
# Step 3551 | Sliding Loss Window : 0.8929949901858815
# Step 3601 | Sliding Loss Window : 1.0469428186816154
# Step 3651 | Sliding Loss Window : 1.0375024082393924
# Step 3701 | Sliding Loss Window : 1.034045011868291
# Step 3751 | Sliding Loss Window : 0.9701185720839267
# Step 3801 | Sliding Loss Window : 0.9271379555569419
# Step 3851 | Sliding Loss Window : 0.9540043964649442
# Step 3901 | Sliding Loss Window : 1.0050715219801312
# Step 3951 | Sliding Loss Window : 0.982607951344809
# Step 4001 | Sliding Loss Window : 0.8867692621196697
# Step 4051 | Sliding Loss Window : 1.0700367378834548
# Step 4101 | Sliding Loss Window : 0.9916546994520716
# Step 4151 | Sliding Loss Window : 1.0272152796946221
# Step 4201 | Sliding Loss Window : 0.9884639380871321
# Step 4251 | Sliding Loss Window : 0.9588501480474801
# Step 4301 | Sliding Loss Window : 0.9015539159813134
# Step 4351 | Sliding Loss Window : 1.019772518254956
# Step 4401 | Sliding Loss Window : 0.8035816890535407
# Step 4451 | Sliding Loss Window : 1.0395230321192712
# Step 4501 | Sliding Loss Window : 1.0090055814299899
# Step 4551 | Sliding Loss Window : 1.1055085155887636
# Step 4601 | Sliding Loss Window : 1.0124539616453516
# Step 4651 | Sliding Loss Window : 1.0741201976376444
# Step 4701 | Sliding Loss Window : 1.0096673628107897
# Step 4751 | Sliding Loss Window : 0.9824425601417015
# Step 4801 | Sliding Loss Window : 1.0126672124052574
# Step 4851 | Sliding Loss Window : 0.9547618760421147
# Step 4901 | Sliding Loss Window : 1.080974430284039
# Step 4951 | Sliding Loss Window : 1.0296086545158198
# Step 5001 | Sliding Loss Window : 1.0118944565646415
# Step 5051 | Sliding Loss Window : 1.017680666750478
# Step 5101 | Sliding Loss Window : 0.9361489531819267
# Step 5151 | Sliding Loss Window : 0.8804867489755793
# Step 5201 | Sliding Loss Window : 1.0450589417210563
# Step 5251 | Sliding Loss Window : 1.0251463012617539
# Step 5301 | Sliding Loss Window : 1.0521522618021293
# Step 5351 | Sliding Loss Window : 0.9729358087632225
# Step 5401 | Sliding Loss Window : 0.9083441671857616
# Step 5451 | Sliding Loss Window : 0.965261915827678
# Step 5501 | Sliding Loss Window : 0.9541711553218609
# Step 5551 | Sliding Loss Window : 1.0425515686816451
# Step 5601 | Sliding Loss Window : 0.8534671583912546
# Step 5651 | Sliding Loss Window : 1.0559464143422779
# Step 5701 | Sliding Loss Window : 0.9767438977351531
# Step 5751 | Sliding Loss Window : 1.008529981453784
# Step 5801 | Sliding Loss Window : 0.941314957336209
# Step 5851 | Sliding Loss Window : 0.9766718987052215
# Step 5901 | Sliding Loss Window : 0.8961389385290177
# Step 5951 | Sliding Loss Window : 1.0489283687189601
# Step 6001 | Sliding Loss Window : 0.8300355321433015
# Step 6051 | Sliding Loss Window : 1.0107244740939976
# Step 6101 | Sliding Loss Window : 0.9926425854737247
# Step 6151 | Sliding Loss Window : 1.0911043013386226
# Step 6201 | Sliding Loss Window : 1.0176894559155496
# Step 6251 | Sliding Loss Window : 1.0862096439846445
# Step 6301 | Sliding Loss Window : 0.9849667658351574
# Step 6351 | Sliding Loss Window : 0.9590171555238679
# Step 6401 | Sliding Loss Window : 1.0445844729758882
# Step 6451 | Sliding Loss Window : 0.923362001132119
# Step 6501 | Sliding Loss Window : 1.0847859855057287
# Step 6551 | Sliding Loss Window : 1.0384049988193345
# Step 6601 | Sliding Loss Window : 1.014785717420591
# Step 6651 | Sliding Loss Window : 1.0176462305835339
# Step 6701 | Sliding Loss Window : 0.9282427010435731
# Step 6751 | Sliding Loss Window : 0.9000438583830028
# Step 6801 | Sliding Loss Window : 1.0521478281723893
# Step 6851 | Sliding Loss Window : 1.000091910956826
# Step 6901 | Sliding Loss Window : 1.039762748229582
# Step 6951 | Sliding Loss Window : 0.9672169875761599
# Step 7001 | Sliding Loss Window : 0.8788484782759959
# Step 7051 | Sliding Loss Window : 0.9782482075219774
# Step 7101 | Sliding Loss Window : 0.9765408319096036
# Step 7151 | Sliding Loss Window : 1.0467996321272122
# Step 7201 | Sliding Loss Window : 0.8562826587196625
# Step 7251 | Sliding Loss Window : 1.0411062276338983
# Step 7301 | Sliding Loss Window : 0.9611397063694868
# Step 7351 | Sliding Loss Window : 1.0111665860153503
# Step 7401 | Sliding Loss Window : 0.9338867103808652
# Step 7451 | Sliding Loss Window : 0.963025099609716
# Step 7501 | Sliding Loss Window : 0.9028372793794707
# Step 7551 | Sliding Loss Window : 1.0201834626419228
# Step 7601 | Sliding Loss Window : 0.8873827436805444
# Step 7651 | Sliding Loss Window : 0.9963825843903896
# Step 7701 | Sliding Loss Window : 1.006899173443497
# Step 7751 | Sliding Loss Window : 1.079982596293272
# Step 7801 | Sliding Loss Window : 1.0150026271095904
# Step 7851 | Sliding Loss Window : 1.060987411938086
# Step 7901 | Sliding Loss Window : 0.9681717955394127
# Step 7951 | Sliding Loss Window : 0.9363609533279903
# Step 1 | Sliding Loss Window : 1.094612529960334
# Step 51 | Sliding Loss Window : 1.0696706045506854
# Step 101 | Sliding Loss Window : 0.9989908170281985
# Step 151 | Sliding Loss Window : 1.007394133360471
